# %%
import pandas as pd

# %%
md_feat_1ehz = pd.read_csv('./dssr_ml_features_complete.csv')

# %%
md_feat_1ehz
# Out:
#    nucleotide  fraction_paired  fraction_wc_paired  fraction_non_wc_paired  \
# 0          G1         1.000000            1.000000                0.001332
# 1          C2         1.000000            0.999334                0.001332
# 2          G3         1.000000            1.000000                0.000666
# 3          G4         1.000000            1.000000                0.000000
# 4          A5         0.998668            0.998668                0.000000
# ..        ...              ...                 ...                     ...
# 71        C72         1.000000            1.000000                0.000000
# 72        A73         0.191206            0.000000                0.191206
# 73        C74         0.001999            0.000000                0.001999
# 74        C75         0.001999            0.000000                0.001999
# 75        A76         0.189873            0.000000                0.189873
#
#     fraction_unpaired  fraction_in_helix  fraction_in_stem  \
# 0            0.000000           1.000000          0.996003
# 1            0.000000           1.000000          0.998001
# 2            0.000000           1.000000          1.000000
# 3            0.000000           1.000000          0.996669
# 4            0.001332           0.998668          0.996669
# ..                ...                ...               ...
# 71           0.000000           1.000000          0.996003
# 72           0.808794           0.190540          0.000000
# 73           0.998001           0.000666          0.000000
# 74           0.998001           0.000000          0.000000
# 75           0.810127           0.189873          0.000000
#
#     fraction_in_hairpin  fraction_in_internal_loop  fraction_in_junction  ...  \
# 0                   0.0                   0.001332                   0.0  ...
# 1                   0.0                   0.001332                   0.0  ...
# 2                   0.0                   0.004664                   0.0  ...
# 3                   0.0                   0.005996                   0.0  ...
# 4                   0.0                   0.014657                   0.0  ...
# ..                  ...                        ...                   ...  ...
# 71                  0.0                   0.001332                   0.0  ...
# 72                  0.0                   0.000000                   0.0  ...
# 73                  0.0                   0.000000                   0.0  ...
# 74                  0.0                   0.000000                   0.0  ...
# 75                  0.0                   0.000000                   0.0  ...
#
#     theta_min  theta_max  phase_angle_mean  phase_angle_std  phase_angle_min  \
# 0         NaN        NaN        115.010158       150.933347            0.017
# 1    -179.659    178.518         34.943058        71.611058            0.006
# 2    -178.664    179.878         48.031193       102.024707            0.006
# 3    -179.465    179.894         49.237387       100.398548            0.109
# 4    -174.906   -103.911         68.332107       124.996793            0.007
# ..        ...        ...               ...              ...              ...
# 71   -178.493    179.863         42.845153        92.995792            0.064
# 72   -179.945    179.951         70.760444       124.701696            0.012
# 73   -179.977    179.219         65.419883        92.513321            0.010
# 74   -179.136    179.864         66.202414        86.542664            0.167
# 75        NaN        NaN        159.369426        88.037980            0.035
#
#     phase_angle_max  amplitude_mean  amplitude_std  amplitude_min  \
# 0           359.943       38.926652       5.104248         18.308
# 1           359.938       40.661071       4.733324         18.333
# 2           359.993       40.992205       4.575773         24.185
# 3           359.981       41.486469       4.559694         25.211
# 4           359.946       39.376840       4.990337         21.907
# ..              ...             ...            ...            ...
# 71          359.888       41.004791       4.753076         22.979
# 72          359.984       38.318017       5.399479         18.310
# 73          359.979       37.851358       5.719728          6.731
# 74          359.936       35.218390       6.625247          4.954
# 75          359.468       35.058227       6.568882          7.554
#
#     amplitude_max
# 0          54.459
# 1          53.833
# 2          54.957
# 3          54.182
# 4          53.131
# ..            ...
# 71         55.044
# 72         55.160
# 73         53.981
# 74         52.732
# 75         54.641
#
# [76 rows x 81 columns]

# %%
numeric_feats = md_feat_1ehz.drop(['nucleotide'], axis=1)

# %%
numeric_feats
# Out:
# Index(['fraction_paired', 'fraction_wc_paired', 'fraction_non_wc_paired',
#        'fraction_unpaired', 'fraction_in_helix', 'fraction_in_stem',
#        'fraction_in_hairpin', 'fraction_in_internal_loop',
#        'fraction_in_junction', 'puckering_C3_endo', 'puckering_C2_endo',
#        'puckering_C4_exo', 'puckering_C1_exo', 'puckering_O4_endo',
#        'puckering_C4_endo', 'puckering_C1_endo', 'puckering_C2_exo',
#        'puckering_C3_exo', 'puckering_O4_exo', 'puckering_other',
#        'sugar_class_C3_endo', 'sugar_class_C2_endo', 'sugar_class_other',
#        'form_A', 'form_B', 'form_other', 'glyco_bond_anti', 'glyco_bond_syn',
#        'glyco_bond_other', 'bb_type_BI', 'bb_type_BII', 'bb_type_other',
#        'alpha_mean', 'alpha_std', 'alpha_min', 'alpha_max', 'beta_mean',
#        'beta_std', 'beta_min', 'beta_max', 'gamma_mean', 'gamma_std',
#        'gamma_min', 'gamma_max', 'delta_mean', 'delta_std', 'delta_min',
#        'delta_max', 'epsilon_mean', 'epsilon_std', 'epsilon_min',
#        'epsilon_max', 'zeta_mean', 'zeta_std', 'zeta_min', 'zeta_max',
#        'epsilon_zeta_mean', 'epsilon_zeta_std', 'epsilon_zeta_min',
#        'epsilon_zeta_max', 'chi_mean', 'chi_std', 'chi_min', 'chi_max',
#        'eta_mean', 'eta_std', 'eta_min', 'eta_max', 'theta_mean', 'theta_std',
#        'theta_min', 'theta_max', 'phase_angle_mean', 'phase_angle_std',
#        'phase_angle_min', 'phase_angle_max', 'amplitude_mean', 'amplitude_std',
#        'amplitude_min', 'amplitude_max'],
#       dtype='object')

# %%
pearson_corr = numeric_feats.corrwith(shape_1ehz['1m7'], method='pearson')

# %%
spearman_corr = numeric_feats.corrwith(shape_1ehz['1m7'], method='spearman')

# %%
corr_df = pd.DataFrame({
    'pearson_r': pearson_corr,
    'spearman_rho': spearman_corr
}).sort_values(by='pearson_r', key=lambda s: s.abs(), ascending=False)

print(corr_df.head(10))

# %%
corr_df.to_csv('correlations.csv')

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr, spearmanr

# Get top features
pearson_corr = numeric_feats.corrwith(numeric_feats['shape_1m7'], method='pearson')
top_features = pearson_corr.abs().sort_values(ascending=False).head(6).index

# Create scatter plots for top 6 features
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.flatten()

for idx, feature in enumerate(top_features):
    ax = axes[idx]
    x = numeric_feats[feature]
    y = numeric_feats['shape_1m7']
    
    # Scatter plot
    ax.scatter(x, y, alpha=0.6, s=50)
    
    # Add regression line
    z = np.polyfit(x, y, 1)
    p = np.poly1d(z)
    ax.plot(x, p(x), "r--", alpha=0.8, linewidth=2)
    
    # Calculate correlations
    r, p_val = pearsonr(x, y)
    rho, _ = spearmanr(x, y)
    
    # Labels
    ax.set_xlabel(feature, fontsize=10)
    ax.set_ylabel('SHAPE Reactivity', fontsize=10)
    ax.set_title(f'{feature}\nPearson r={r:.3f}, Spearman ρ={rho:.3f}', fontsize=9)
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('correlation_plots.png', dpi=300, bbox_inches='tight')
plt.show()
