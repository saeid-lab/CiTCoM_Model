# %%
# Importing a few libraries:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import os
import re
from pathlib import Path
import mdtraj as md
import nglview as nv
import argparse
from collections import defaultdict
pd.set_option('display.max_columns', None)
pd.set_option('display.max_row', None)

# %% [markdown]
# """
# alpha, beta, gamma, delta, epsilon, zeta
# epsilon_zeta
# chi
# eta, theta
# eta_prime, theta_prime
# eta_base, theta_base
# v0–v4
# amplitude
# phase_angle
# ssZp
# Dp
# splay_angle
# splay_distance
# splay_ratio
#
# mean - std - min - max
#
#
# 2. Discrete conformational states → probabilities
#
# For categorical fields:
# puckering
# sugar_class
# bb_type
# bin
# cluster
# glyco_bond
# form
# For each category:
# One-hot fraction of frames
#
# Example:
# puckering_C3_endo = 0.73
# puckering_C2_endo = 0.21
# puckering_other = 0.06
#
# Also compute:
# Shannon entropy per categorical field
#
# 3. Base pairing & secondary structure occupancy
# From pairs, stems, helices, hairpins, etc.
# Per nucleotide:
# Fraction paired
# Fraction WC paired
# Fraction non-WC paired
# Fraction unpaired
# Fraction in helix
# Fraction in stem
# Fraction in hairpin loop
# Fraction in internal loop
# Fraction in junction
# Fraction at helix end
# Fraction at stem end
# This is core SHAPE signal. Do not skip it.
#
#
# 4. Pairing dynamics (still “keeping everything”, but smarter)
#
# From the paired/unpaired time series:
# Mean paired run length
# Mean unpaired run length
# Number of transitions per microsecond
# Max continuous paired stretch
# These are not redundant with occupancy.
#
#
# 5. Stacking & tertiary interactions
# Per nucleotide:
# Fraction in stacking
# Fraction in multiplets
# Fraction in coaxial stacks
# Fraction in splay units
# Fraction involved in A-minor
# Fraction in atom–base contacts
# These often explain outliers in SHAPE.
#
#
# 6. Frame-level noise control (important)
#
# Add:
# Number of valid frames used for this nucleotide
# Some residues will be missing in DSSR occasionally. The model needs to know that.
#
# """

# %%
json_url = './pdbs.json'
with open(json_url) as f:
    dssr_json = json.load(f)

# %%
models = dssr_json['models']

nts_list = []
for nt in dssr_json['models'][0]['parameters']['nts']:
    index = nt['index']
    name = nt['nt_id'].split(':')[1]
    nts_list.append([index, name])

nt_ids = [nt for _, nt in nts_list]
nt_index = {nt: i for i, nt in enumerate(nt_ids)}

n_nt = len(nts_list)
n_frames = len(models)
pair_matrix = np.zeros((n_nt, n_frames), dtype=np.uint8)

for f, m in enumerate(models):
    for pair in m['parameters'].get('pairs', []):
        i = nt_index[pair['nt1'].split(':')[1]]
        j = nt_index[pair['nt2'].split(':')[1]]
        pair_matrix[i, f] = 1
        pair_matrix[j, f] = 1

pair_df = pd.DataFrame(pair_matrix, index=nt_ids)

# %%
wc_matrix = np.zeros((n_nt, n_frames), dtype=np.uint8)
non_wc_matrix = np.zeros((n_nt, n_frames), dtype=np.uint8)

for f, m in enumerate(models):
    for pair in m['parameters'].get('pairs', []):
        i = nt_index[pair['nt1'].split(':')[1]]
        j = nt_index[pair['nt2'].split(':')[1]]
        
        # Check if WC pair (cWW classification in LW or DSSR field)
        lw_class = pair.get('LW', '')
        dssr_class = pair.get('DSSR', '')
        
        if 'cWW' in lw_class or 'cW-W' in dssr_class:
            wc_matrix[i, f] = 1
            wc_matrix[j, f] = 1
        else:
            non_wc_matrix[i, f] = 1
            non_wc_matrix[j, f] = 1

wc_df = pd.DataFrame(wc_matrix, index=nt_ids)
non_wc_df = pd.DataFrame(non_wc_matrix, index=nt_ids)

# %%
len(models)
# Out:
# 1501

# %%
pair_df

# %%
pair_df.to_csv('pairing.csv')

# %%
multi_matrix = np.zeros((n_nt, n_frames), dtype=np.uint8)

for f, m in enumerate(models):
    for mp in m['parameters'].get('multiplets', []):
        nts = mp['nts_long'].split(',')
        for nt in nts:
            nt_name = nt.split(':')[1]
            multi_matrix[nt_index[nt_name], f] = 1

multi_df = pd.DataFrame(multi_matrix, index=nt_ids)

# %%
helices_matrix = np.zeros((n_nt, n_frames), dtype=np.uint8)

for f, m in enumerate(models):
    for mp in m['parameters'].get('helices', []):
        index = mp['pairs']
        for nt in index:
            i = nt_index[nt['nt1'].split(':')[1]]
            j = nt_index[nt['nt2'].split(':')[1]]
            helices_matrix[i, f] = 1
            helices_matrix[j, f] = 1

helices_df = pd.DataFrame(helices_matrix, index=nt_ids)

# %%
stems_matrix = np.zeros((n_nt, n_frames), dtype=np.uint8)

for f, m in enumerate(models):
    for mp in m['parameters'].get('stems', []):
        index = mp['pairs']
        for nt in index:
            i = nt_index[nt['nt1'].split(':')[1]]
            j = nt_index[nt['nt2'].split(':')[1]]
            stems_matrix[i, f] = 1
            stems_matrix[j, f] = 1

stems_df = pd.DataFrame(stems_matrix, index=nt_ids)

# %%
hairpin_matrix = np.zeros((n_nt, n_frames), dtype=np.uint8)

for f, m in enumerate(models):
    for hairpin in m['parameters'].get('hairpins', []):
        nts_in_loop = hairpin.get('nts_long', '').split(',')
        for nt_id in nts_in_loop:
            nt_name = nt_id.split(':')[1] if ':' in nt_id else nt_id.strip()
            if nt_name in nt_index:
                i = nt_index[nt_name]
                hairpin_matrix[i, f] = 1

hairpin_df = pd.DataFrame(hairpin_matrix, index=nt_ids)

# %%
internal_loop_matrix = np.zeros((n_nt, n_frames), dtype=np.uint8)

for f, m in enumerate(models):
    # Process internal loops
    for iloop in m['parameters'].get('iloops', []):
        nts_in_loop = iloop.get('nts_long', '').split(',')
        for nt_id in nts_in_loop:
            nt_name = nt_id.split(':')[1] if ':' in nt_id else nt_id.strip()
            if nt_name in nt_index:
                i = nt_index[nt_name]
                internal_loop_matrix[i, f] = 1
    
    # Process bulges (a special type of internal loop)
    for bulge in m['parameters'].get('bulges', []):
        nts_in_loop = bulge.get('nts_long', '').split(',')
        for nt_id in nts_in_loop:
            nt_name = nt_id.split(':')[1] if ':' in nt_id else nt_id.strip()
            if nt_name in nt_index:
                i = nt_index[nt_name]
                internal_loop_matrix[i, f] = 1

internal_loop_df = pd.DataFrame(internal_loop_matrix, index=nt_ids)

# %%
junction_matrix = np.zeros((n_nt, n_frames), dtype=np.uint8)
for f, m in enumerate(models):
    for junction in m['parameters'].get('junctions', []):
        nts_in_loop = junction.get('nts_long', '').split(',')
        for nt_id in nts_in_loop:
            nt_name = nt_id.split(':')[1] if ':' in nt_id else nt_id.strip()
            if nt_name in nt_index:
                i = nt_index[nt_name]
                junction_matrix[i, f] = 1

junction_df = pd.DataFrame(junction_matrix, index=nt_ids)

# %%
df = pd.DataFrame(nts_list, columns=['nuc_index', 'nt_name'])
df.set_index('nt_name', inplace=True)

# %%
models[0]['parameters'].keys()
# Out:
# dict_keys(['num_pairs', 'pairs', 'num_multiplets', 'multiplets', 'num_helices', 'helices', 'num_stems', 'stems', 'num_coaxStacks', 'coaxStacks', 'num_stacks', 'stacks', 'nonStack', 'num_atom2bases', 'atom2bases', 'num_hairpins', 'hairpins', 'num_iloops', 'iloops', 'num_junctions', 'junctions', 'num_ssSegments', 'ssSegments', 'num_Aminors', 'Aminors', 'num_splayUnits', 'splayUnits', 'dbn', 'chains', 'num_nts', 'nts', 'num_hbonds', 'hbonds', 'refCoords', 'metadata'])

# %%
models[0]['parameters'].get('pairs')
# Out:
# [{'index': 1,
#   'nt1': '1:U1',
#   'nt2': '1:A119',
#   'bp': 'U-A',
#   'name': 'WC',
#   'Saenger': '20-XX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 2,
#   'nt1': '1:G2',
#   'nt2': '1:C118',
#   'bp': 'G-C',
#   'name': 'WC',
#   'Saenger': '19-XIX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 3,
#   'nt1': '1:C3',
#   'nt2': '1:G117',
#   'bp': 'C-G',
#   'name': 'WC',
#   'Saenger': '19-XIX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 4,
#   'nt1': '1:C4',
#   'nt2': '1:G116',
#   'bp': 'C-G',
#   'name': 'WC',
#   'Saenger': '19-XIX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 5,
#   'nt1': '1:U5',
#   'nt2': '1:A115',
#   'bp': 'U-A',
#   'name': 'WC',
#   'Saenger': '20-XX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 6,
#   'nt1': '1:G6',
#   'nt2': '1:C114',
#   'bp': 'G-C',
#   'name': 'WC',
#   'Saenger': '19-XIX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 7,
#   'nt1': '1:G7',
#   'nt2': '1:C113',
#   'bp': 'G-C',
#   'name': 'WC',
#   'Saenger': '19-XIX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 8,
#   'nt1': '1:C8',
#   'nt2': '1:G112',
#   'bp': 'C-G',
#   'name': 'WC',
#   'Saenger': '19-XIX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 9,
#   'nt1': '1:G9',
#   'nt2': '1:U111',
#   'bp': 'G-U',
#   'name': 'Wobble',
#   'Saenger': '28-XXVIII',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 10,
#   'nt1': '1:G10',
#   'nt2': '1:C110',
#   'bp': 'G-C',
#   'name': 'WC',
#   'Saenger': '19-XIX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 11,
#   'nt1': '1:C12',
#   'nt2': '1:A109',
#   'bp': 'C-A',
#   'name': '--',
#   'Saenger': '--',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 12,
#   'nt1': '1:G16',
#   'nt2': '1:C68',
#   'bp': 'G-C',
#   'name': 'WC',
#   'Saenger': '19-XIX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 13,
#   'nt1': '1:G16',
#   'nt2': '1:G107',
#   'bp': 'G+G',
#   'name': '--',
#   'Saenger': '06-VI',
#   'LW': 'cHW',
#   'DSSR': 'cM+W'},
#  {'index': 14,
#   'nt1': '1:C17',
#   'nt2': '1:G67',
#   'bp': 'C-G',
#   'name': 'WC',
#   'Saenger': '19-XIX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 15,
#   'nt1': '1:G18',
#   'nt2': '1:U65',
#   'bp': 'G-U',
#   'name': '--',
#   'Saenger': '--',
#   'LW': 'cW.',
#   'DSSR': 'cW-.'},
#  {'index': 16,
#   'nt1': '1:C19',
#   'nt2': '1:G64',
#   'bp': 'C-G',
#   'name': 'WC',
#   'Saenger': '19-XIX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 17,
#   'nt1': '1:G20',
#   'nt2': '1:C63',
#   'bp': 'G-C',
#   'name': 'WC',
#   'Saenger': '19-XIX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 18,
#   'nt1': '1:G21',
#   'nt2': '1:C62',
#   'bp': 'G-C',
#   'name': 'WC',
#   'Saenger': '19-XIX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 19,
#   'nt1': '1:U22',
#   'nt2': '1:G61',
#   'bp': 'U-G',
#   'name': 'Wobble',
#   'Saenger': '28-XXVIII',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 20,
#   'nt1': '1:G23',
#   'nt2': '1:G56',
#   'bp': 'G+G',
#   'name': '--',
#   'Saenger': '--',
#   'LW': 't.H',
#   'DSSR': 't.+M'},
#  {'index': 21,
#   'nt1': '1:G23',
#   'nt2': '1:C60',
#   'bp': 'G-C',
#   'name': 'WC',
#   'Saenger': '19-XIX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 22,
#   'nt1': '1:C31',
#   'nt2': '1:G51',
#   'bp': 'C-G',
#   'name': 'WC',
#   'Saenger': '19-XIX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 23,
#   'nt1': '1:U32',
#   'nt2': '1:A50',
#   'bp': 'U-A',
#   'name': 'WC',
#   'Saenger': '20-XX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 24,
#   'nt1': '1:G33',
#   'nt2': '1:C49',
#   'bp': 'G-C',
#   'name': 'WC',
#   'Saenger': '19-XIX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 25,
#   'nt1': '1:A34',
#   'nt2': '1:U48',
#   'bp': 'A-U',
#   'name': 'WC',
#   'Saenger': '20-XX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 26,
#   'nt1': '1:C42',
#   'nt2': '1:G44',
#   'bp': 'C-G',
#   'name': '--',
#   'Saenger': '--',
#   'LW': 'cSW',
#   'DSSR': 'cm-W'},
#  {'index': 27,
#   'nt1': '1:A66',
#   'nt2': '1:G69',
#   'bp': 'A+G',
#   'name': '--',
#   'Saenger': '--',
#   'LW': 'cSW',
#   'DSSR': 'cm+W'},
#  {'index': 28,
#   'nt1': '1:C68',
#   'nt2': '1:G107',
#   'bp': 'C-G',
#   'name': '--',
#   'Saenger': '--',
#   'LW': '..W',
#   'DSSR': '..-W'},
#  {'index': 29,
#   'nt1': '1:C70',
#   'nt2': '1:G106',
#   'bp': 'C-G',
#   'name': 'WC',
#   'Saenger': '19-XIX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 30,
#   'nt1': '1:C71',
#   'nt2': '1:G105',
#   'bp': 'C-G',
#   'name': 'WC',
#   'Saenger': '19-XIX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 31,
#   'nt1': '1:G72',
#   'nt2': '1:A104',
#   'bp': 'G-A',
#   'name': 'Sheared',
#   'Saenger': '11-XI',
#   'LW': 'tSH',
#   'DSSR': 'tm-M'},
#  {'index': 32,
#   'nt1': '1:A73',
#   'nt2': '1:U103',
#   'bp': 'A-U',
#   'name': 'rHoogsteen',
#   'Saenger': '24-XXIV',
#   'LW': 'tHW',
#   'DSSR': 'tM-W'},
#  {'index': 33,
#   'nt1': '1:U74',
#   'nt2': '1:G102',
#   'bp': 'U-G',
#   'name': '--',
#   'Saenger': '--',
#   'LW': 'tHW',
#   'DSSR': 'tM-W'},
#  {'index': 34,
#   'nt1': '1:G75',
#   'nt2': '1:A101',
#   'bp': 'G-A',
#   'name': '--',
#   'Saenger': '--',
#   'LW': 'c.W',
#   'DSSR': 'c.-W'},
#  {'index': 35,
#   'nt1': '1:G76',
#   'nt2': '1:G100',
#   'bp': 'G-G',
#   'name': '--',
#   'Saenger': '--',
#   'LW': 'tWH',
#   'DSSR': 'tW-M'},
#  {'index': 36,
#   'nt1': '1:U77',
#   'nt2': '1:A99',
#   'bp': 'U-A',
#   'name': 'rHoogsteen',
#   'Saenger': '24-XXIV',
#   'LW': 'tWH',
#   'DSSR': 'tW-M'},
#  {'index': 37,
#   'nt1': '1:A78',
#   'nt2': '1:G98',
#   'bp': 'A-G',
#   'name': 'Sheared',
#   'Saenger': '11-XI',
#   'LW': 'tHS',
#   'DSSR': 'tM-m'},
#  {'index': 38,
#   'nt1': '1:G79',
#   'nt2': '1:C97',
#   'bp': 'G-C',
#   'name': 'WC',
#   'Saenger': '19-XIX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 39,
#   'nt1': '1:U80',
#   'nt2': '1:G96',
#   'bp': 'U-G',
#   'name': 'Wobble',
#   'Saenger': '28-XXVIII',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 40,
#   'nt1': '1:G81',
#   'nt2': '1:U95',
#   'bp': 'G-U',
#   'name': 'Wobble',
#   'Saenger': '28-XXVIII',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 41,
#   'nt1': '1:U82',
#   'nt2': '1:A94',
#   'bp': 'U-A',
#   'name': 'WC',
#   'Saenger': '20-XX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 42,
#   'nt1': '1:G83',
#   'nt2': '1:C93',
#   'bp': 'G-C',
#   'name': 'WC',
#   'Saenger': '19-XIX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 43,
#   'nt1': '1:G84',
#   'nt2': '1:C92',
#   'bp': 'G-C',
#   'name': 'WC',
#   'Saenger': '19-XIX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 44,
#   'nt1': '1:G85',
#   'nt2': '1:C91',
#   'bp': 'G-C',
#   'name': 'WC',
#   'Saenger': '19-XIX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'},
#  {'index': 45,
#   'nt1': '1:G86',
#   'nt2': '1:C90',
#   'bp': 'G-C',
#   'name': 'WC',
#   'Saenger': '19-XIX',
#   'LW': 'cWW',
#   'DSSR': 'cW-W'}]

# %%
fraction_paired = pair_df.mean(axis=1)
fraction_wc_paired = wc_df.mean(axis=1)
fraction_non_wc_paired = non_wc_df.mean(axis=1)
fraction_unpaired = 1 - fraction_paired
fraction_in_multiplet = multi_df.mean(axis=1)
fraction_in_helix = helices_df.mean(axis=1)
fraction_in_stem = stems_df.mean(axis=1)
fraction_in_hairpin = hairpin_df.mean(axis=1)
fraction_in_internal_loop = internal_loop_df.mean(axis=1)
fraction_in_junction = junction_df.mean(axis=1)

# fraction_wc_paired = wc_df.mean(axis=1)
# fraction_non_wc_paired = non_wc_df.mean(axis=1)

# %%
features_df = pd.DataFrame({
    'nucleotide': nt_ids,
    'fraction_paired': fraction_paired,
    'fraction_wc_paired': fraction_wc_paired,
    'fraction_non_wc_paired': fraction_non_wc_paired,
    'fraction_unpaired': fraction_unpaired,
    'fraction_in_helix': fraction_in_helix,
    'fraction_in_stem': fraction_in_stem,
    'fraction_in_hairpin': fraction_in_hairpin,
    'fraction_in_internal_loop': fraction_in_internal_loop,
    'fraction_in_junction': fraction_in_junction,
})

# %%
features_df
# Out:
#      nucleotide  fraction_paired  fraction_wc_paired  fraction_non_wc_paired  \
# U1           U1         0.804797            0.734177                0.123251
# G2           G2         0.999334            0.997335                0.003331
# C3           C3         1.000000            1.000000                0.003331
# C4           C4         1.000000            1.000000                0.007328
# U5           U5         0.999334            0.996669                0.012658
# G6           G6         1.000000            1.000000                0.007328
# G7           G7         1.000000            1.000000                0.000000
# C8           C8         1.000000            1.000000                0.000000
# G9           G9         0.758827            0.757495                0.001332
# G10         G10         0.658228            0.656895                0.019320
# C11         C11         0.014657            0.000000                0.014657
# C12         C12         0.392405            0.329780                0.177215
# G13         G13         0.411059            0.084610                0.377082
# U14         U14         0.017322            0.000000                0.017322
# A15         A15         0.203864            0.000000                0.203864
# G16         G16         0.999334            0.999334                0.374417
# C17         C17         1.000000            0.999334                0.152565
# U77              0.000000                   1.000000              0.000000
# A78              0.000000                   1.000000              0.000000
# G79              0.000000                   1.000000              0.000000
# U80              0.000000                   0.002665              0.000000
# G81              0.000000                   0.002665              0.000000
# U82              0.000000                   0.001332              0.000000
# G83              0.000000                   0.000666              0.000000
# G84              0.000000                   0.000000              0.000000
# G85              0.007995                   0.000000              0.000000
# G86              1.000000                   0.000000              0.000000
# U87              1.000000                   0.000000              0.000000
# C88              1.000000                   0.000000              0.000000
# U89              1.000000                   0.000000              0.000000
# C90              1.000000                   0.000000              0.000000
# C91              0.007995                   0.000000              0.000000
# C92              0.000000                   0.000000              0.000000
# C93              0.000000                   0.000666              0.000000
# A94              0.000000                   0.001332              0.000000
# U95              0.000000                   0.002665              0.000000
# G96              0.000000                   0.002665              0.000000
# C97              0.000000                   1.000000              0.000000
# G98              0.000000                   1.000000              0.000000
# A99              0.000000                   1.000000              0.000000
# G100             0.000000                   1.000000              0.000000
# A101             0.000000                   1.000000              0.000000
# G102             0.000000                   1.000000              0.000000
# U103             0.000000                   1.000000              0.000000
# A104             0.000000                   1.000000              0.000000
# G105             0.000000                   1.000000              0.009993
# G106             0.000000                   0.000000              1.000000
# G107             0.000000                   0.324450              1.000000
# A108             0.000000                   0.324450              0.675550
# A109             0.000000                   0.324450              0.675550
# C110             0.000000                   0.326449              0.675550
# U111             0.000000                   0.271153              0.131246
# G112             0.000000                   0.262492              0.000666
# C113             0.000000                   0.007995              0.000000
# C114             0.000000                   0.086609              0.000000
# A115             0.000000                   0.086609              0.000000
# G116             0.000000                   0.086609              0.000000
# G117             0.000000                   0.001999              0.000000
# C118             0.000000                   0.001999              0.000000
# A119             0.000000                   0.001999              0.000000
# U120             0.000000                   0.000000              0.000000

# %%
models[0]['parameters'].keys()
# Out:
# dict_keys(['num_pairs', 'pairs', 'num_multiplets', 'multiplets', 'num_helices', 'helices', 'num_stems', 'stems', 'num_coaxStacks', 'coaxStacks', 'num_stacks', 'stacks', 'nonStack', 'num_atom2bases', 'atom2bases', 'num_hairpins', 'hairpins', 'num_iloops', 'iloops', 'num_junctions', 'junctions', 'num_ssSegments', 'ssSegments', 'num_Aminors', 'Aminors', 'num_splayUnits', 'splayUnits', 'dbn', 'chains', 'num_nts', 'nts', 'num_hbonds', 'hbonds', 'refCoords', 'metadata'])

# %%
models[0]['parameters'].get('nts')
# Out:
# [{'index': 1,
#   'index_chain': 1,
#   'chain_name': ' ',
#   'nt_resnum': 1,
#   'nt_name': 'U',
#   'nt_code': 'U',
#   'nt_id': '1:U1',
#   'linked_nts': [None, '1:G2'],
#   'nt_type': 'RNA',
#   'dbn': '(',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix-end,stem-end",
#   'alpha': None,
#   'beta': None,
#   'gamma': 50.752,
#   'delta': 92.364,
#   'epsilon': -164.021,
#   'zeta': -64.499,
#   'epsilon_zeta': -99.522,
#   'bb_type': 'BI',
#   'chi': -151.595,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-2.161, 8.887, -0.738],
#   'P_xyz': [None, None, None],
#   'form': '.',
#   'ssZp': 3.233,
#   'Dp': 4.11,
#   'splay_angle': 19.495,
#   'splay_distance': 3.523,
#   'splay_ratio': 0.176,
#   'eta': None,
#   'theta': None,
#   'eta_prime': None,
#   'theta_prime': None,
#   'eta_base': None,
#   'theta_base': None,
#   'v0': -15.076,
#   'v1': -4.935,
#   'v2': 20.779,
#   'v3': -29.149,
#   'v4': 28.384,
#   'amplitude': 30.253,
#   'phase_angle': 46.62,
#   'puckering': "C4'-exo",
#   'sugar_class': "~C3'-endo",
#   'bin': 'inc',
#   'cluster': '__',
#   'suiteness': 0.0,
#   'filter_rmsd': 0.108,
#   'frame': {'rmsd': 0.071,
#    'origin': [121.947, 137.861, 67.251],
#    'x_axis': [-0.08, 0.417, -0.905],
#    'y_axis': [0.306, -0.854, -0.421],
#    'z_axis': [-0.949, -0.311, -0.059],
#    'quaternion': [0.041, -0.677, -0.267, 0.685]}},
#  {'index': 2,
#   'index_chain': 2,
#   'chain_name': ' ',
#   'nt_resnum': 2,
#   'nt_name': 'G',
#   'nt_code': 'G',
#   'nt_id': '1:G2',
#   'linked_nts': ['1:U1', '1:C3'],
#   'nt_type': 'RNA',
#   'dbn': '(',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem",
#   'alpha': -79.041,
#   'beta': 160.636,
#   'gamma': 64.273,
#   'delta': 80.154,
#   'epsilon': -173.408,
#   'zeta': -73.179,
#   'epsilon_zeta': -100.228,
#   'bb_type': 'BI',
#   'chi': -152.342,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-2.508, 9.124, -0.213],
#   'P_xyz': [-0.283, 10.496, -0.343],
#   'form': 'A',
#   'ssZp': 3.774,
#   'Dp': 4.319,
#   'splay_angle': 23.547,
#   'splay_distance': 3.953,
#   'splay_ratio': 0.206,
#   'eta': 154.988,
#   'theta': -160.405,
#   'eta_prime': 172.696,
#   'theta_prime': -160.911,
#   'eta_base': -145.534,
#   'theta_base': -132.891,
#   'v0': -10.803,
#   'v1': -15.05,
#   'v2': 31.81,
#   'v3': -37.67,
#   'v4': 33.443,
#   'amplitude': 38.522,
#   'phase_angle': 34.333,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.474,
#   'filter_rmsd': 0.062,
#   'frame': {'rmsd': 0.062,
#    'origin': [118.503, 138.283, 66.643],
#    'x_axis': [0.302, 0.012, -0.953],
#    'y_axis': [0.276, -0.958, 0.075],
#    'z_axis': [-0.912, -0.286, -0.293],
#    'quaternion': [0.113, 0.799, 0.09, -0.584]}},
#  {'index': 3,
#   'index_chain': 3,
#   'chain_name': ' ',
#   'nt_resnum': 3,
#   'nt_name': 'C',
#   'nt_code': 'C',
#   'nt_id': '1:C3',
#   'linked_nts': ['1:G2', '1:C4'],
#   'nt_type': 'RNA',
#   'dbn': '(',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem",
#   'alpha': -90.546,
#   'beta': 179.308,
#   'gamma': 72.862,
#   'delta': 77.033,
#   'epsilon': -153.267,
#   'zeta': -76.284,
#   'epsilon_zeta': -76.983,
#   'bb_type': 'BI',
#   'chi': -140.658,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.771, 8.978, 0.087],
#   'P_xyz': [0.657, 9.851, -0.326],
#   'form': 'A',
#   'ssZp': 4.464,
#   'Dp': 4.397,
#   'splay_angle': 19.727,
#   'splay_distance': 3.326,
#   'splay_ratio': 0.176,
#   'eta': 162.48,
#   'theta': -150.293,
#   'eta_prime': 172.674,
#   'theta_prime': -152.239,
#   'eta_base': -148.321,
#   'theta_base': -131.465,
#   'v0': 8.621,
#   'v1': -23.62,
#   'v2': 28.072,
#   'v3': -26.476,
#   'v4': 11.085,
#   'amplitude': 28.125,
#   'phase_angle': 3.523,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.174,
#   'filter_rmsd': 0.069,
#   'frame': {'rmsd': 0.037,
#    'origin': [114.944, 138.455, 64.93],
#    'x_axis': [0.388, -0.491, -0.78],
#    'y_axis': [0.043, -0.836, 0.548],
#    'z_axis': [-0.921, -0.246, -0.303],
#    'quaternion': [0.249, 0.795, -0.141, -0.535]}},
#  {'index': 4,
#   'index_chain': 4,
#   'chain_name': ' ',
#   'nt_resnum': 4,
#   'nt_name': 'C',
#   'nt_code': 'C',
#   'nt_id': '1:C4',
#   'linked_nts': ['1:C3', '1:U5'],
#   'nt_type': 'RNA',
#   'dbn': '(',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem",
#   'alpha': -69.515,
#   'beta': 173.486,
#   'gamma': 60.68,
#   'delta': 80.25,
#   'epsilon': -151.778,
#   'zeta': -67.875,
#   'epsilon_zeta': -83.903,
#   'bb_type': 'BI',
#   'chi': -157.497,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.842, 8.978, -0.491],
#   'P_xyz': [0.656, 9.76, -1.095],
#   'form': 'A',
#   'ssZp': 3.837,
#   'Dp': 4.584,
#   'splay_angle': 20.995,
#   'splay_distance': 3.534,
#   'splay_ratio': 0.184,
#   'eta': 166.205,
#   'theta': -144.664,
#   'eta_prime': 177.552,
#   'theta_prime': -145.314,
#   'eta_base': -149.329,
#   'theta_base': -121.489,
#   'v0': -7.657,
#   'v1': -20.57,
#   'v2': 36.458,
#   'v3': -43.071,
#   'v4': 33.565,
#   'amplitude': 41.927,
#   'phase_angle': 29.592,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.858,
#   'filter_rmsd': 0.112,
#   'frame': {'rmsd': 0.096,
#    'origin': [112.775, 138.446, 62.408],
#    'x_axis': [0.502, -0.773, -0.388],
#    'y_axis': [-0.385, -0.601, 0.7],
#    'z_axis': [-0.774, -0.202, -0.6],
#    'quaternion': [0.274, 0.822, -0.352, -0.353]}},
#  {'index': 5,
#   'index_chain': 5,
#   'chain_name': ' ',
#   'nt_resnum': 5,
#   'nt_name': 'U',
#   'nt_code': 'U',
#   'nt_id': '1:U5',
#   'linked_nts': ['1:C4', '1:G6'],
#   'nt_type': 'RNA',
#   'dbn': '(',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem,A-minor",
#   'alpha': -70.844,
#   'beta': -173.131,
#   'gamma': 52.756,
#   'delta': 79.615,
#   'epsilon': -166.862,
#   'zeta': -76.261,
#   'epsilon_zeta': -90.601,
#   'bb_type': 'BI',
#   'chi': -128.688,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.721, 8.756, -0.838],
#   'P_xyz': [0.692, 9.763, -1.177],
#   'form': '.',
#   'ssZp': 3.543,
#   'Dp': 4.352,
#   'splay_angle': 26.053,
#   'splay_distance': 4.285,
#   'splay_ratio': 0.226,
#   'eta': 171.223,
#   'theta': -161.9,
#   'eta_prime': -177.466,
#   'theta_prime': -159.282,
#   'eta_base': -143.594,
#   'theta_base': -132.498,
#   'v0': 7.887,
#   'v1': -30.297,
#   'v2': 38.882,
#   'v3': -37.529,
#   'v4': 19.278,
#   'amplitude': 39.35,
#   'phase_angle': 8.845,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.9,
#   'filter_rmsd': 0.1,
#   'frame': {'rmsd': 0.041,
#    'origin': [111.626, 136.998, 59.397],
#    'x_axis': [0.457, -0.869, 0.189],
#    'y_axis': [-0.723, -0.239, 0.648],
#    'z_axis': [-0.517, -0.433, -0.738],
#    'quaternion': [0.346, 0.78, -0.51, -0.105]}},
#  {'index': 6,
#   'index_chain': 6,
#   'chain_name': ' ',
#   'nt_resnum': 6,
#   'nt_name': 'G',
#   'nt_code': 'G',
#   'nt_id': '1:G6',
#   'linked_nts': ['1:U5', '1:G7'],
#   'nt_type': 'RNA',
#   'dbn': '(',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem",
#   'alpha': -77.999,
#   'beta': 171.884,
#   'gamma': 60.417,
#   'delta': 70.9,
#   'epsilon': -165.288,
#   'zeta': -48.284,
#   'epsilon_zeta': -117.004,
#   'bb_type': 'BI',
#   'chi': -154.103,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.192, 8.941, 0.008],
#   'P_xyz': [1.391, 9.147, 0.191],
#   'form': 'A',
#   'ssZp': 3.916,
#   'Dp': 4.573,
#   'splay_angle': 22.063,
#   'splay_distance': 3.69,
#   'splay_ratio': 0.198,
#   'eta': 160.055,
#   'theta': -137.839,
#   'eta_prime': 171.481,
#   'theta_prime': -140.884,
#   'eta_base': -151.264,
#   'theta_base': -118.228,
#   'v0': 12.282,
#   'v1': -34.101,
#   'v2': 41.597,
#   'v3': -37.507,
#   'v4': 16.262,
#   'amplitude': 41.666,
#   'phase_angle': 3.302,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.542,
#   'filter_rmsd': 0.066,
#   'frame': {'rmsd': 0.066,
#    'origin': [109.839, 134.403, 56.494],
#    'x_axis': [0.315, -0.548, 0.775],
#    'y_axis': [-0.847, 0.207, 0.49],
#    'z_axis': [-0.429, -0.811, -0.399],
#    'quaternion': [0.53, 0.614, -0.568, 0.141]}},
#  {'index': 7,
#   'index_chain': 7,
#   'chain_name': ' ',
#   'nt_resnum': 7,
#   'nt_name': 'G',
#   'nt_code': 'G',
#   'nt_id': '1:G7',
#   'linked_nts': ['1:G6', '1:C8'],
#   'nt_type': 'RNA',
#   'dbn': '(',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem",
#   'alpha': -88.577,
#   'beta': 178.036,
#   'gamma': 66.283,
#   'delta': 84.419,
#   'epsilon': -162.46,
#   'zeta': -80.898,
#   'epsilon_zeta': -81.562,
#   'bb_type': 'BI',
#   'chi': -166.777,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.497, 8.867, 0.818],
#   'P_xyz': [0.905, 9.728, 0.818],
#   'form': 'A',
#   'ssZp': 4.437,
#   'Dp': 4.473,
#   'splay_angle': 23.901,
#   'splay_distance': 3.734,
#   'splay_ratio': 0.21,
#   'eta': 163.554,
#   'theta': -158.835,
#   'eta_prime': -178.175,
#   'theta_prime': -155.003,
#   'eta_base': -134.178,
#   'theta_base': -129.792,
#   'v0': -4.609,
#   'v1': -20.022,
#   'v2': 35.607,
#   'v3': -38.692,
#   'v4': 26.647,
#   'amplitude': 39.128,
#   'phase_angle': 24.493,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.241,
#   'filter_rmsd': 0.054,
#   'frame': {'rmsd': 0.054,
#    'origin': [110.107, 130.903, 55.357],
#    'x_axis': [-0.118, -0.305, 0.945],
#    'y_axis': [-0.89, 0.454, 0.035],
#    'z_axis': [-0.44, -0.837, -0.325],
#    'quaternion': [0.503, 0.434, -0.689, 0.291]}},
#  {'index': 8,
#   'index_chain': 8,
#   'chain_name': ' ',
#   'nt_resnum': 8,
#   'nt_name': 'C',
#   'nt_code': 'C',
#   'nt_id': '1:C8',
#   'linked_nts': ['1:G7', '1:G9'],
#   'nt_type': 'RNA',
#   'dbn': '(',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem",
#   'alpha': -60.013,
#   'beta': 167.333,
#   'gamma': 62.123,
#   'delta': 87.515,
#   'epsilon': -159.571,
#   'zeta': -55.123,
#   'epsilon_zeta': -104.448,
#   'bb_type': 'BI',
#   'chi': -157.831,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.898, 8.847, 0.288],
#   'P_xyz': [0.748, 9.16, 0.55],
#   'form': '.',
#   'ssZp': 3.953,
#   'Dp': 4.615,
#   'splay_angle': 24.546,
#   'splay_distance': 4.27,
#   'splay_ratio': 0.22,
#   'eta': 176.861,
#   'theta': -119.877,
#   'eta_prime': -169.324,
#   'theta_prime': -126.405,
#   'eta_base': -135.16,
#   'theta_base': -97.273,
#   'v0': -4.345,
#   'v1': -20.572,
#   'v2': 34.591,
#   'v3': -39.003,
#   'v4': 27.816,
#   'amplitude': 38.298,
#   'phase_angle': 25.418,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.7,
#   'filter_rmsd': 0.069,
#   'frame': {'rmsd': 0.031,
#    'origin': [110.11, 127.216, 54.767],
#    'x_axis': [-0.496, 0.022, 0.868],
#    'y_axis': [-0.756, 0.481, -0.444],
#    'z_axis': [-0.428, -0.876, -0.222],
#    'quaternion': [-0.437, -0.247, 0.741, -0.445]}},
#  {'index': 9,
#   'index_chain': 9,
#   'chain_name': ' ',
#   'nt_resnum': 9,
#   'nt_name': 'G',
#   'nt_code': 'G',
#   'nt_id': '1:G9',
#   'linked_nts': ['1:C8', '1:G10'],
#   'nt_type': 'RNA',
#   'dbn': '(',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem",
#   'alpha': -99.137,
#   'beta': -178.883,
#   'gamma': 72.877,
#   'delta': 85.245,
#   'epsilon': -170.232,
#   'zeta': -85.268,
#   'epsilon_zeta': -84.965,
#   'bb_type': 'BI',
#   'chi': -171.154,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-2.355, 8.965, 0.813],
#   'P_xyz': [-0.039, 10.214, 1.007],
#   'form': 'A',
#   'ssZp': 4.507,
#   'Dp': 4.106,
#   'splay_angle': 22.244,
#   'splay_distance': 3.728,
#   'splay_ratio': 0.198,
#   'eta': 156.954,
#   'theta': -163.336,
#   'eta_prime': -179.38,
#   'theta_prime': -164.759,
#   'eta_base': -125.396,
#   'theta_base': -153.242,
#   'v0': -23.197,
#   'v1': -1.472,
#   'v2': 22.649,
#   'v3': -37.473,
#   'v4': 39.452,
#   'amplitude': 39.248,
#   'phase_angle': 54.755,
#   'puckering': "C4'-exo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.086,
#   'filter_rmsd': 0.043,
#   'frame': {'rmsd': 0.043,
#    'origin': [108.182, 123.77, 56.393],
#    'x_axis': [-0.774, 0.461, 0.434],
#    'y_axis': [-0.252, 0.405, -0.879],
#    'z_axis': [-0.581, -0.79, -0.197],
#    'quaternion': [-0.329, 0.068, 0.771, -0.541]}},
#  {'index': 10,
#   'index_chain': 10,
#   'chain_name': ' ',
#   'nt_resnum': 10,
#   'nt_name': 'G',
#   'nt_code': 'G',
#   'nt_id': '1:G10',
#   'linked_nts': ['1:G9', '1:C11'],
#   'nt_type': 'RNA',
#   'dbn': '(',
#   'summary': "anti,~C3'-endo,canonical,non-pair-contact,helix,stem-end,junction-loop,splayed-apart",
#   'alpha': -81.428,
#   'beta': 177.575,
#   'gamma': 64.072,
#   'delta': 85.127,
#   'epsilon': -77.695,
#   'zeta': -152.648,
#   'epsilon_zeta': 74.952,
#   'bb_type': '--',
#   'chi': -148.591,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.838, 8.962, -0.045],
#   'P_xyz': [0.618, 9.787, -0.835],
#   'form': '.',
#   'ssZp': 3.694,
#   'Dp': 4.429,
#   'splay_angle': 117.755,
#   'splay_distance': 17.913,
#   'splay_ratio': 0.856,
#   'eta': -176.798,
#   'theta': -138.786,
#   'eta_prime': -177.809,
#   'theta_prime': -176.741,
#   'eta_base': -165.247,
#   'theta_base': -176.414,
#   'v0': -0.531,
#   'v1': -20.414,
#   'v2': 30.73,
#   'v3': -32.114,
#   'v4': 20.364,
#   'amplitude': 32.504,
#   'phase_angle': 19.016,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.475,
#   'filter_rmsd': 0.059,
#   'frame': {'rmsd': 0.059,
#    'origin': [107.677, 120.311, 57.688],
#    'x_axis': [-0.89, 0.453, 0.045],
#    'y_axis': [-0.062, -0.022, -0.998],
#    'z_axis': [-0.451, -0.891, 0.048],
#    'quaternion': [0.184, -0.145, -0.675, 0.7]}},
#  {'index': 11,
#   'index_chain': 11,
#   'chain_name': ' ',
#   'nt_resnum': 11,
#   'nt_name': 'C',
#   'nt_code': 'C',
#   'nt_id': '1:C11',
#   'linked_nts': ['1:G10', '1:C12'],
#   'nt_type': 'RNA',
#   'dbn': '.',
#   'summary': "turn,anti,~C3'-endo,non-stack,junction-loop,splayed-apart",
#   'alpha': 56.438,
#   'beta': -159.412,
#   'gamma': -82.005,
#   'delta': -39.321,
#   'epsilon': -102.816,
#   'zeta': 84.892,
#   'epsilon_zeta': 172.292,
#   'bb_type': '--',
#   'chi': 179.385,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-3.166, 8.639, 0.986],
#   'P_xyz': [-4.95, 9.639, -0.695],
#   'form': '.',
#   'ssZp': 4.64,
#   'Dp': 4.905,
#   'splay_angle': 117.574,
#   'splay_distance': 16.91,
#   'splay_ratio': 0.858,
#   'eta': 126.418,
#   'theta': -99.639,
#   'eta_prime': 105.665,
#   'theta_prime': -53.822,
#   'eta_base': 76.122,
#   'theta_base': -48.592,
#   'v0': 22.426,
#   'v1': -37.542,
#   'v2': 39.027,
#   'v3': -26.783,
#   'v4': 2.505,
#   'amplitude': 40.28,
#   'phase_angle': 345.671,
#   'puckering': "C2'-exo",
#   'sugar_class': "~C3'-endo",
#   'bin': 'trig',
#   'cluster': '!!',
#   'suiteness': 0.0,
#   'filter_rmsd': 0.099,
#   'frame': {'rmsd': 0.051,
#    'origin': [107.596, 104.988, 48.411],
#    'x_axis': [0.174, -0.474, 0.863],
#    'y_axis': [-0.005, 0.876, 0.482],
#    'z_axis': [-0.985, -0.088, 0.15],
#    'quaternion': [0.742, 0.192, -0.623, -0.158]}},
#  {'index': 12,
#   'index_chain': 12,
#   'chain_name': ' ',
#   'nt_resnum': 12,
#   'nt_name': 'C',
#   'nt_code': 'C',
#   'nt_id': '1:C12',
#   'linked_nts': ['1:C11', '1:G13'],
#   'nt_type': 'RNA',
#   'dbn': '.',
#   'summary': 'anti,non-canonical,non-pair-contact,helix-end,junction-loop,splayed-apart',
#   'alpha': -94.184,
#   'beta': 155.623,
#   'gamma': -173.548,
#   'delta': 4.193,
#   'epsilon': -172.242,
#   'zeta': 54.459,
#   'epsilon_zeta': 133.299,
#   'bb_type': '--',
#   'chi': -179.983,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-2.45, 8.764, 1.211],
#   'P_xyz': [-2.063, 10.852, -0.378],
#   'form': '.',
#   'ssZp': 3.736,
#   'Dp': 4.119,
#   'splay_angle': 39.663,
#   'splay_distance': 6.117,
#   'splay_ratio': 0.34,
#   'eta': -81.289,
#   'theta': -131.644,
#   'eta_prime': -87.495,
#   'theta_prime': -129.571,
#   'eta_base': -48.178,
#   'theta_base': -84.9,
#   'v0': 39.584,
#   'v1': -33.017,
#   'v2': 16.216,
#   'v3': 6.461,
#   'v4': -30.781,
#   'amplitude': 39.201,
#   'phase_angle': 294.435,
#   'puckering': "C1'-endo",
#   'sugar_class': '--',
#   'bin': 'trig',
#   'cluster': '!!',
#   'suiteness': 0.0,
#   'filter_rmsd': 0.064,
#   'frame': {'rmsd': 0.055,
#    'origin': [106.527, 119.707, 56.666],
#    'x_axis': [-0.75, 0.661, -0.022],
#    'y_axis': [-0.526, -0.616, -0.587],
#    'z_axis': [-0.401, -0.428, 0.81],
#    'quaternion': [0.333, -0.119, -0.285, 0.891]}},
#  {'index': 13,
#   'index_chain': 13,
#   'chain_name': ' ',
#   'nt_resnum': 13,
#   'nt_name': 'G',
#   'nt_code': 'G',
#   'nt_id': '1:G13',
#   'linked_nts': ['1:C12', '1:U14'],
#   'nt_type': 'RNA',
#   'dbn': '.',
#   'summary': "turn,u-turn,anti,~C3'-endo,non-pair-contact,junction-loop,cap-donor,phosphate,splayed-apart",
#   'alpha': 163.244,
#   'beta': 169.928,
#   'gamma': 62.042,
#   'delta': 90.844,
#   'epsilon': -81.407,
#   'zeta': -48.961,
#   'epsilon_zeta': -32.446,
#   'bb_type': '--',
#   'chi': 176.633,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.174, 8.169, 1.867],
#   'P_xyz': [1.38, 8.575, 1.702],
#   'form': '.',
#   'ssZp': 5.06,
#   'Dp': 4.762,
#   'splay_angle': 89.268,
#   'splay_distance': 12.666,
#   'splay_ratio': 0.703,
#   'eta': 86.796,
#   'theta': -27.133,
#   'eta_prime': 134.672,
#   'theta_prime': -56.207,
#   'eta_base': -159.565,
#   'theta_base': -118.362,
#   'v0': 7.629,
#   'v1': -26.482,
#   'v2': 32.997,
#   'v3': -31.092,
#   'v4': 15.089,
#   'amplitude': 33.229,
#   'phase_angle': 6.778,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': 'trig',
#   'cluster': '!!',
#   'suiteness': 0.0,
#   'filter_rmsd': 0.067,
#   'frame': {'rmsd': 0.067,
#    'origin': [101.031, 117.839, 58.593],
#    'x_axis': [0.114, 0.233, -0.966],
#    'y_axis': [0.647, -0.755, -0.106],
#    'z_axis': [-0.754, -0.612, -0.237],
#    'quaternion': [0.174, 0.726, 0.303, -0.592]}},
#  {'index': 14,
#   'index_chain': 14,
#   'chain_name': ' ',
#   'nt_resnum': 14,
#   'nt_name': 'U',
#   'nt_code': 'U',
#   'nt_id': '1:U14',
#   'linked_nts': ['1:G13', '1:A15'],
#   'nt_type': 'RNA',
#   'dbn': '.',
#   'summary': "turn,u-turn,anti,~C3'-endo,non-stack,non-pair-contact,junction-loop,splayed-apart",
#   'alpha': 87.547,
#   'beta': 154.656,
#   'gamma': 69.468,
#   'delta': 86.969,
#   'epsilon': 167.537,
#   'zeta': 156.567,
#   'epsilon_zeta': 10.97,
#   'bb_type': '--',
#   'chi': 178.966,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.559, 8.303, 1.749],
#   'P_xyz': [1.092, 8.785, 1.512],
#   'form': '.',
#   'ssZp': 4.337,
#   'Dp': 4.221,
#   'splay_angle': 103.378,
#   'splay_distance': 12.508,
#   'splay_ratio': 0.785,
#   'eta': -73.605,
#   'theta': 31.595,
#   'eta_prime': -13.072,
#   'theta_prime': -143.614,
#   'eta_base': 39.834,
#   'theta_base': 175.309,
#   'v0': 8.288,
#   'v1': -30.591,
#   'v2': 38.172,
#   'v3': -34.978,
#   'v4': 17.51,
#   'amplitude': 38.427,
#   'phase_angle': 6.607,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '!!',
#   'suiteness': 0.0,
#   'filter_rmsd': 0.082,
#   'frame': {'rmsd': 0.056,
#    'origin': [93.175, 108.312, 55.771],
#    'x_axis': [-0.264, -0.203, 0.943],
#    'y_axis': [0.964, -0.084, 0.252],
#    'z_axis': [0.028, 0.976, 0.218],
#    'quaternion': [-0.467, 0.388, 0.49, 0.626]}},
#  {'index': 15,
#   'index_chain': 15,
#   'chain_name': ' ',
#   'nt_resnum': 15,
#   'nt_name': 'A',
#   'nt_code': 'A',
#   'nt_id': '1:A15',
#   'linked_nts': ['1:U14', '1:G16'],
#   'nt_type': 'RNA',
#   'dbn': '.',
#   'summary': 'turn,u-turn,anti,non-stack,non-pair-contact,junction-loop,phosphate,splayed-apart',
#   'alpha': -120.412,
#   'beta': -77.493,
#   'gamma': 178.255,
#   'delta': -5.991,
#   'epsilon': -116.987,
#   'zeta': 87.709,
#   'epsilon_zeta': 155.304,
#   'bb_type': '--',
#   'chi': -74.553,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-4.369, 6.264, -2.76],
#   'P_xyz': [-4.385, 4.61, -4.75],
#   'form': '.',
#   'ssZp': -2.343,
#   'Dp': 4.673,
#   'splay_angle': 139.267,
#   'splay_distance': 19.376,
#   'splay_ratio': 0.938,
#   'eta': -47.952,
#   'theta': 7.248,
#   'eta_prime': 98.225,
#   'theta_prime': 11.969,
#   'eta_base': 97.849,
#   'theta_base': -30.515,
#   'v0': 33.377,
#   'v1': -32.279,
#   'v2': 21.871,
#   'v3': -3.555,
#   'v4': -18.845,
#   'amplitude': 34.206,
#   'phase_angle': 309.745,
#   'puckering': "C1'-endo",
#   'sugar_class': '--',
#   'bin': 'trig',
#   'cluster': '!!',
#   'suiteness': 0.0,
#   'filter_rmsd': 0.087,
#   'frame': {'rmsd': 0.072,
#    'origin': [97.008, 116.991, 47.62],
#    'x_axis': [-0.939, 0.32, -0.128],
#    'y_axis': [-0.011, 0.342, 0.94],
#    'z_axis': [0.344, 0.884, -0.318],
#    'quaternion': [0.146, 0.096, 0.806, 0.565]}},
#  {'index': 16,
#   'index_chain': 16,
#   'chain_name': ' ',
#   'nt_resnum': 16,
#   'nt_name': 'G',
#   'nt_code': 'G',
#   'nt_id': '1:G16',
#   'linked_nts': ['1:A15', '1:C17'],
#   'nt_type': 'RNA',
#   'dbn': '(',
#   'summary': "u-turn,anti,~C3'-endo,BI,canonical,non-canonical,non-pair-contact,helix,stem-end,coaxial-stack,multiplet,junction-loop,cap-acceptor,phosphate,splayed-apart",
#   'alpha': 83.697,
#   'beta': -175.875,
#   'gamma': -62.09,
#   'delta': 86.394,
#   'epsilon': -148.53,
#   'zeta': -75.726,
#   'epsilon_zeta': -72.804,
#   'bb_type': 'BI',
#   'chi': -172.905,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.206, 8.362, 1.302],
#   'P_xyz': [-0.654, 10.128, 3.266],
#   'form': 'A',
#   'ssZp': 4.501,
#   'Dp': 4.744,
#   'splay_angle': 27.08,
#   'splay_distance': 4.031,
#   'splay_ratio': 0.236,
#   'eta': -113.963,
#   'theta': 178.218,
#   'eta_prime': -111.817,
#   'theta_prime': -163.04,
#   'eta_base': -52.762,
#   'theta_base': -109.835,
#   'v0': 8.53,
#   'v1': -30.897,
#   'v2': 37.692,
#   'v3': -36.058,
#   'v4': 18.206,
#   'amplitude': 37.999,
#   'phase_angle': 7.289,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': 'trig',
#   'cluster': '!!',
#   'suiteness': 0.0,
#   'filter_rmsd': 0.066,
#   'frame': {'rmsd': 0.066,
#    'origin': [97.859, 111.074, 66.051],
#    'x_axis': [0.346, 0.705, 0.619],
#    'y_axis': [0.322, 0.53, -0.784],
#    'z_axis': [-0.881, 0.471, -0.044],
#    'quaternion': [0.677, -0.464, -0.554, 0.141]}},
#  {'index': 17,
#   'index_chain': 17,
#   'chain_name': ' ',
#   'nt_resnum': 17,
#   'nt_name': 'C',
#   'nt_code': 'C',
#   'nt_id': '1:C17',
#   'linked_nts': ['1:G16', '1:G18'],
#   'nt_type': 'RNA',
#   'dbn': '(',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem-end,coaxial-stack,internal-loop",
#   'alpha': -61.176,
#   'beta': 176.239,
#   'gamma': 52.11,
#   'delta': 80.372,
#   'epsilon': -145.346,
#   'zeta': -69.649,
#   'epsilon_zeta': -75.697,
#   'bb_type': 'BI',
#   'chi': -168.119,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.499, 8.548, 0.858],
#   'P_xyz': [1.072, 8.596, 1.561],
#   'form': 'A',
#   'ssZp': 4.173,
#   'Dp': 4.633,
#   'splay_angle': 27.984,
#   'splay_distance': 4.415,
#   'splay_ratio': 0.246,
#   'eta': 170.856,
#   'theta': -138.063,
#   'eta_prime': -175.652,
#   'theta_prime': -136.145,
#   'eta_base': -128.501,
#   'theta_base': -112.201,
#   'v0': 18.081,
#   'v1': -34.94,
#   'v2': 39.35,
#   'v3': -30.636,
#   'v4': 7.944,
#   'amplitude': 39.629,
#   'phase_angle': 353.2,
#   'puckering': "C2'-exo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.916,
#   'filter_rmsd': 0.085,
#   'frame': {'rmsd': 0.052,
#    'origin': [94.868, 113.144, 67.788],
#    'x_axis': [0.659, 0.752, -0.02],
#    'y_axis': [0.052, -0.072, -0.996],
#    'z_axis': [-0.75, 0.656, -0.087],
#    'quaternion': [0.612, -0.674, -0.298, 0.286]}},
#  {'index': 18,
#   'index_chain': 18,
#   'chain_name': ' ',
#   'nt_resnum': 18,
#   'nt_name': 'G',
#   'nt_code': 'G',
#   'nt_id': '1:G18',
#   'linked_nts': ['1:C17', '1:C19'],
#   'nt_type': 'RNA',
#   'dbn': '.',
#   'summary': "anti,~C3'-endo,BI,non-canonical,non-pair-contact,helix,internal-loop",
#   'alpha': -78.393,
#   'beta': 179.765,
#   'gamma': 69.472,
#   'delta': 73.176,
#   'epsilon': -159.797,
#   'zeta': -68.041,
#   'epsilon_zeta': -91.756,
#   'bb_type': 'BI',
#   'chi': -169.5,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.447, 8.797, 1.199],
#   'P_xyz': [1.193, 9.194, 1.51],
#   'form': 'A',
#   'ssZp': 4.51,
#   'Dp': 4.636,
#   'splay_angle': 21.832,
#   'splay_distance': 3.718,
#   'splay_ratio': 0.201,
#   'eta': 171.4,
#   'theta': -150.893,
#   'eta_prime': -172.414,
#   'theta_prime': -151.239,
#   'eta_base': -130.084,
#   'theta_base': -145.919,
#   'v0': 6.197,
#   'v1': -27.948,
#   'v2': 37.582,
#   'v3': -35.83,
#   'v4': 18.493,
#   'amplitude': 38.15,
#   'phase_angle': 9.896,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.478,
#   'filter_rmsd': 0.086,
#   'frame': {'rmsd': 0.086,
#    'origin': [92.438, 116.595, 69.083],
#    'x_axis': [0.592, 0.55, -0.588],
#    'y_axis': [-0.235, -0.581, -0.78],
#    'z_axis': [-0.771, 0.6, -0.214],
#    'quaternion': [-0.446, 0.773, 0.102, -0.44]}},
#  {'index': 19,
#   'index_chain': 19,
#   'chain_name': ' ',
#   'nt_resnum': 19,
#   'nt_name': 'C',
#   'nt_code': 'C',
#   'nt_id': '1:C19',
#   'linked_nts': ['1:G18', '1:G20'],
#   'nt_type': 'RNA',
#   'dbn': '(',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem-end,coaxial-stack,internal-loop",
#   'alpha': -66.806,
#   'beta': 168.959,
#   'gamma': 64.752,
#   'delta': 65.975,
#   'epsilon': -144.49,
#   'zeta': -67.492,
#   'epsilon_zeta': -76.998,
#   'bb_type': 'BI',
#   'chi': -149.744,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.633, 9.051, -0.318],
#   'P_xyz': [0.936, 9.826, -0.372],
#   'form': 'A',
#   'ssZp': 3.768,
#   'Dp': 4.719,
#   'splay_angle': 19.664,
#   'splay_distance': 3.305,
#   'splay_ratio': 0.173,
#   'eta': 175.816,
#   'theta': -146.456,
#   'eta_prime': -176.041,
#   'theta_prime': -147.216,
#   'eta_base': -160.845,
#   'theta_base': -120.3,
#   'v0': -7.791,
#   'v1': -17.897,
#   'v2': 36.157,
#   'v3': -42.14,
#   'v4': 29.58,
#   'amplitude': 41.329,
#   'phase_angle': 28.973,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.336,
#   'filter_rmsd': 0.052,
#   'frame': {'rmsd': 0.04,
#    'origin': [90.859, 119.349, 71.02],
#    'x_axis': [0.416, 0.342, -0.843],
#    'y_axis': [-0.612, -0.58, -0.538],
#    'z_axis': [-0.672, 0.74, -0.032],
#    'quaternion': [-0.449, 0.712, -0.095, -0.532]}},
#  {'index': 20,
#   'index_chain': 20,
#   'chain_name': ' ',
#   'nt_resnum': 20,
#   'nt_name': 'G',
#   'nt_code': 'G',
#   'nt_id': '1:G20',
#   'linked_nts': ['1:C19', '1:G21'],
#   'nt_type': 'RNA',
#   'dbn': '(',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem,coaxial-stack",
#   'alpha': -63.631,
#   'beta': 163.428,
#   'gamma': 46.79,
#   'delta': 87.693,
#   'epsilon': -157.63,
#   'zeta': -74.649,
#   'epsilon_zeta': -82.981,
#   'bb_type': 'BI',
#   'chi': -159.21,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.584, 8.945, 0.216],
#   'P_xyz': [0.745, 9.784, -0.414],
#   'form': 'A',
#   'ssZp': 4.42,
#   'Dp': 4.611,
#   'splay_angle': 24.596,
#   'splay_distance': 4.013,
#   'splay_ratio': 0.218,
#   'eta': 157.119,
#   'theta': -151.482,
#   'eta_prime': 173.645,
#   'theta_prime': -154.108,
#   'eta_base': -143.007,
#   'theta_base': -130.777,
#   'v0': 0.06,
#   'v1': -25.432,
#   'v2': 39.765,
#   'v3': -40.933,
#   'v4': 26.685,
#   'amplitude': 42.055,
#   'phase_angle': 18.994,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.376,
#   'filter_rmsd': 0.101,
#   'frame': {'rmsd': 0.101,
#    'origin': [89.906, 122.46, 70.437],
#    'x_axis': [0.134, -0.041, -0.99],
#    'y_axis': [-0.817, -0.569, -0.087],
#    'z_axis': [-0.56, 0.821, -0.11],
#    'quaternion': [-0.337, 0.673, -0.319, -0.576]}},
#  {'index': 21,
#   'index_chain': 21,
#   'chain_name': ' ',
#   'nt_resnum': 21,
#   'nt_name': 'G',
#   'nt_code': 'G',
#   'nt_id': '1:G21',
#   'linked_nts': ['1:G20', '1:U22'],
#   'nt_type': 'RNA',
#   'dbn': '(',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem,coaxial-stack",
#   'alpha': -76.198,
#   'beta': 167.479,
#   'gamma': 67.549,
#   'delta': 81.599,
#   'epsilon': -150.152,
#   'zeta': -72.014,
#   'epsilon_zeta': -78.138,
#   'bb_type': 'BI',
#   'chi': -167.526,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.93, 8.519, 1.628],
#   'P_xyz': [0.633, 9.477, 1.652],
#   'form': '.',
#   'ssZp': 4.884,
#   'Dp': 4.637,
#   'splay_angle': 31.691,
#   'splay_distance': 4.843,
#   'splay_ratio': 0.276,
#   'eta': 167.896,
#   'theta': -141.054,
#   'eta_prime': -179.638,
#   'theta_prime': -140.901,
#   'eta_base': -139.247,
#   'theta_base': -104.269,
#   'v0': 2.205,
#   'v1': -29.168,
#   'v2': 41.487,
#   'v3': -43.228,
#   'v4': 26.504,
#   'amplitude': 43.319,
#   'phase_angle': 16.722,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.577,
#   'filter_rmsd': 0.098,
#   'frame': {'rmsd': 0.098,
#    'origin': [89.524, 126.07, 68.727],
#    'x_axis': [-0.108, -0.51, -0.853],
#    'y_axis': [-0.759, -0.512, 0.402],
#    'z_axis': [-0.642, 0.691, -0.332],
#    'quaternion': [-0.11, 0.659, -0.482, -0.568]}},
#  {'index': 22,
#   'index_chain': 22,
#   'chain_name': ' ',
#   'nt_resnum': 22,
#   'nt_name': 'U',
#   'nt_code': 'U',
#   'nt_id': '1:U22',
#   'linked_nts': ['1:G21', '1:G23'],
#   'nt_type': 'RNA',
#   'dbn': '(',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem,coaxial-stack",
#   'alpha': -65.946,
#   'beta': 168.979,
#   'gamma': 60.125,
#   'delta': 71.058,
#   'epsilon': -163.381,
#   'zeta': -68.358,
#   'epsilon_zeta': -95.022,
#   'bb_type': 'BI',
#   'chi': -174.992,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.601, 8.464, 1.754],
#   'P_xyz': [0.94, 8.876, 2.007],
#   'form': '.',
#   'ssZp': 4.962,
#   'Dp': 4.699,
#   'splay_angle': 20.822,
#   'splay_distance': 3.741,
#   'splay_ratio': 0.209,
#   'eta': 167.796,
#   'theta': -153.82,
#   'eta_prime': -177.734,
#   'theta_prime': -152.066,
#   'eta_base': -118.944,
#   'theta_base': -160.157,
#   'v0': 2.832,
#   'v1': -27.676,
#   'v2': 37.059,
#   'v3': -39.382,
#   'v4': 22.773,
#   'amplitude': 38.459,
#   'phase_angle': 15.508,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.693,
#   'filter_rmsd': 0.088,
#   'frame': {'rmsd': 0.05,
#    'origin': [87.547, 128.235, 64.872],
#    'x_axis': [-0.635, -0.691, -0.346],
#    'y_axis': [-0.382, -0.108, 0.918],
#    'z_axis': [-0.672, 0.714, -0.196],
#    'quaternion': [-0.124, -0.409, 0.656, 0.622]}},
#  {'index': 23,
#   'index_chain': 23,
#   'chain_name': ' ',
#   'nt_resnum': 23,
#   'nt_name': 'G',
#   'nt_code': 'G',
#   'nt_id': '1:G23',
#   'linked_nts': ['1:U22', '1:G24'],
#   'nt_type': 'RNA',
#   'dbn': '(',
#   'summary': "anti,~C3'-endo,BI,canonical,non-canonical,non-pair-contact,helix-end,stem-end,coaxial-stack,multiplet,internal-loop",
#   'alpha': -85.89,
#   'beta': -172.802,
#   'gamma': 65.514,
#   'delta': 76.677,
#   'epsilon': -164.659,
#   'zeta': -94.586,
#   'epsilon_zeta': -70.073,
#   'bb_type': 'BI',
#   'chi': -150.285,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.801, 8.931, 0.079],
#   'P_xyz': [0.611, 9.883, 0.105],
#   'form': '.',
#   'ssZp': 4.242,
#   'Dp': 4.287,
#   'splay_angle': 77.685,
#   'splay_distance': 13.07,
#   'splay_ratio': 0.631,
#   'eta': 171.709,
#   'theta': -152.914,
#   'eta_prime': 177.296,
#   'theta_prime': 169.239,
#   'eta_base': 175.535,
#   'theta_base': 165.157,
#   'v0': 2.746,
#   'v1': -21.125,
#   'v2': 28.906,
#   'v3': -30.269,
#   'v4': 17.478,
#   'amplitude': 29.929,
#   'phase_angle': 15.023,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.379,
#   'filter_rmsd': 0.043,
#   'frame': {'rmsd': 0.043,
#    'origin': [88.34, 130.085, 61.718],
#    'x_axis': [-0.576, -0.815, 0.059],
#    'y_axis': [-0.411, 0.352, 0.841],
#    'z_axis': [-0.706, 0.46, -0.538],
#    'quaternion': [-0.244, -0.391, 0.785, 0.414]}},
#  {'index': 24,
#   'index_chain': 24,
#   'chain_name': ' ',
#   'nt_resnum': 24,
#   'nt_name': 'G',
#   'nt_code': 'G',
#   'nt_id': '1:G24',
#   'linked_nts': ['1:G23', '1:U25'],
#   'nt_type': 'RNA',
#   'dbn': '.',
#   'summary': 'anti,non-pair-contact,internal-loop',
#   'alpha': 104.426,
#   'beta': -176.016,
#   'gamma': -66.234,
#   'delta': -0.96,
#   'epsilon': -114.841,
#   'zeta': -60.815,
#   'epsilon_zeta': -54.026,
#   'bb_type': '--',
#   'chi': 165.807,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-2.847, 8.181, 2.227],
#   'P_xyz': [-4.652, 10.119, 1.952],
#   'form': '.',
#   'ssZp': 4.269,
#   'Dp': 4.764,
#   'splay_angle': 24.992,
#   'splay_distance': 4.231,
#   'splay_ratio': 0.23,
#   'eta': -179.425,
#   'theta': 142.02,
#   'eta_prime': 147.508,
#   'theta_prime': -179.272,
#   'eta_base': 123.21,
#   'theta_base': -136.541,
#   'v0': 48.417,
#   'v1': -41.405,
#   'v2': 23.541,
#   'v3': 4.162,
#   'v4': -33.475,
#   'amplitude': 47.637,
#   'phase_angle': 299.615,
#   'puckering': "C1'-endo",
#   'sugar_class': '--',
#   'bin': 'trig',
#   'cluster': '!!',
#   'suiteness': 0.0,
#   'filter_rmsd': 0.04,
#   'frame': {'rmsd': 0.04,
#    'origin': [88.778, 142.226, 56.899],
#    'x_axis': [0.506, -0.627, -0.592],
#    'y_axis': [-0.084, -0.719, 0.69],
#    'z_axis': [-0.859, -0.299, -0.416],
#    'quaternion': [0.304, 0.813, -0.219, -0.446]}},
#  {'index': 25,
#   'index_chain': 25,
#   'chain_name': ' ',
#   'nt_resnum': 25,
#   'nt_name': 'U',
#   'nt_code': 'U',
#   'nt_id': '1:U25',
#   'linked_nts': ['1:G24', '1:C26'],
#   'nt_type': 'RNA',
#   'dbn': '.',
#   'summary': "anti,~C2'-endo,non-pair-contact,internal-loop,phosphate,splayed-apart",
#   'alpha': -76.351,
#   'beta': -171.78,
#   'gamma': 62.168,
#   'delta': 146.522,
#   'epsilon': -100.36,
#   'zeta': -77.713,
#   'epsilon_zeta': -22.647,
#   'bb_type': '--',
#   'chi': -120.506,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-2.568, 8.722, -0.718],
#   'P_xyz': [-0.383, 9.913, 0.288],
#   'form': '.',
#   'ssZp': 1.279,
#   'Dp': 1.349,
#   'splay_angle': 87.178,
#   'splay_distance': 13.09,
#   'splay_ratio': 0.69,
#   'eta': 175.314,
#   'theta': -51.53,
#   'eta_prime': -139.439,
#   'theta_prime': -64.4,
#   'eta_base': -103.569,
#   'theta_base': -39.159,
#   'v0': -29.254,
#   'v1': 39.231,
#   'v2': -32.658,
#   'v3': 17.423,
#   'v4': 6.859,
#   'amplitude': 37.692,
#   'phase_angle': 150.047,
#   'puckering': "C2'-endo",
#   'sugar_class': "~C2'-endo",
#   'bin': 'trig',
#   'cluster': '!!',
#   'suiteness': 0.0,
#   'filter_rmsd': 0.107,
#   'frame': {'rmsd': 0.058,
#    'origin': [87.004, 141.417, 53.145],
#    'x_axis': [0.405, -0.913, 0.043],
#    'y_axis': [-0.446, -0.156, 0.881],
#    'z_axis': [-0.798, -0.376, -0.47],
#    'quaternion': [0.441, 0.713, -0.477, -0.265]}},
#  {'index': 26,
#   'index_chain': 26,
#   'chain_name': ' ',
#   'nt_resnum': 26,
#   'nt_name': 'C',
#   'nt_code': 'C',
#   'nt_id': '1:C26',
#   'linked_nts': ['1:U25', '1:C27'],
#   'nt_type': 'RNA',
#   'dbn': '.',
#   'summary': "anti,~C2'-endo,non-pair-contact,internal-loop,splayed-apart",
#   'alpha': -85.276,
#   'beta': -167.642,
#   'gamma': 61.841,
#   'delta': 134.677,
#   'epsilon': 80.149,
#   'zeta': -56.348,
#   'epsilon_zeta': -223.503,
#   'bb_type': '--',
#   'chi': -107.473,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.63, 8.23, -1.806],
#   'P_xyz': [0.905, 8.947, -1.364],
#   'form': 'Z',
#   'ssZp': 0.44,
#   'Dp': 1.15,
#   'splay_angle': 19.438,
#   'splay_distance': 3.534,
#   'splay_ratio': 0.188,
#   'eta': 127.365,
#   'theta': -164.41,
#   'eta_prime': -130.7,
#   'theta_prime': 120.092,
#   'eta_base': -113.07,
#   'theta_base': 104.613,
#   'v0': -16.507,
#   'v1': 32.665,
#   'v2': -34.72,
#   'v3': 27.333,
#   'v4': -7.723,
#   'amplitude': 35.021,
#   'phase_angle': 172.475,
#   'puckering': "C2'-endo",
#   'sugar_class': "~C2'-endo",
#   'bin': '22p',
#   'cluster': '2[',
#   'suiteness': 0.41,
#   'filter_rmsd': 0.06,
#   'frame': {'rmsd': 0.03,
#    'origin': [77.042, 137.214, 60.524],
#    'x_axis': [0.757, -0.034, 0.653],
#    'y_axis': [0.168, 0.975, -0.144],
#    'z_axis': [-0.632, 0.219, 0.744],
#    'quaternion': [0.932, -0.097, -0.344, -0.054]}},
#  {'index': 27,
#   'index_chain': 27,
#   'chain_name': ' ',
#   'nt_resnum': 27,
#   'nt_name': 'C',
#   'nt_code': 'C',
#   'nt_id': '1:C27',
#   'linked_nts': ['1:C26', '1:C28'],
#   'nt_type': 'RNA',
#   'dbn': '.',
#   'summary': "anti,~C2'-endo,non-pair-contact,internal-loop,phosphate,splayed-apart",
#   'alpha': -72.154,
#   'beta': -166.655,
#   'gamma': 43.561,
#   'delta': 138.056,
#   'epsilon': -86.764,
#   'zeta': -106.888,
#   'epsilon_zeta': 20.124,
#   'bb_type': '--',
#   'chi': -171.455,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-3.292, 8.611, 0.954],
#   'P_xyz': [-3.174, 9.007, 3.577],
#   'form': '.',
#   'ssZp': -0.747,
#   'Dp': 1.18,
#   'splay_angle': 126.997,
#   'splay_distance': 17.359,
#   'splay_ratio': 0.895,
#   'eta': -173.968,
#   'theta': -57.175,
#   'eta_prime': 174.545,
#   'theta_prime': -104.251,
#   'eta_base': 154.946,
#   'theta_base': -142.984,
#   'v0': -42.054,
#   'v1': 51.351,
#   'v2': -38.342,
#   'v3': 14.337,
#   'v4': 17.71,
#   'amplitude': 49.587,
#   'phase_angle': 140.644,
#   'puckering': "C1'-exo",
#   'sugar_class': "~C2'-endo",
#   'bin': 'trig',
#   'cluster': '!!',
#   'suiteness': 0.0,
#   'filter_rmsd': 0.068,
#   'frame': {'rmsd': 0.049,
#    'origin': [78.115, 134.916, 58.063],
#    'x_axis': [0.847, 0.17, 0.504],
#    'y_axis': [0.013, 0.941, -0.338],
#    'z_axis': [-0.532, 0.293, 0.795],
#    'quaternion': [0.946, -0.167, -0.274, 0.041]}},
#  {'index': 28,
#   'index_chain': 28,
#   'chain_name': ' ',
#   'nt_resnum': 28,
#   'nt_name': 'C',
#   'nt_code': 'C',
#   'nt_id': '1:C28',
#   'linked_nts': ['1:C27', '1:A29'],
#   'nt_type': 'RNA',
#   'dbn': '.',
#   'summary': "turn,anti,~C3'-endo,non-stack,non-pair-contact,internal-loop,splayed-apart",
#   'alpha': 53.692,
#   'beta': -174.968,
#   'gamma': 45.818,
#   'delta': 81.117,
#   'epsilon': -160.072,
#   'zeta': 48.891,
#   'epsilon_zeta': 151.037,
#   'bb_type': '--',
#   'chi': -131.773,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.866, 8.964, -0.778],
#   'P_xyz': [0.583, 9.872, -0.942],
#   'form': '.',
#   'ssZp': 3.629,
#   'Dp': 4.182,
#   'splay_angle': 117.102,
#   'splay_distance': 17.568,
#   'splay_ratio': 0.854,
#   'eta': -84.411,
#   'theta': -5.743,
#   'eta_prime': -31.144,
#   'theta_prime': -21.691,
#   'eta_base': 7.415,
#   'theta_base': -21.847,
#   'v0': -10.18,
#   'v1': -11.502,
#   'v2': 27.991,
#   'v3': -36.654,
#   'v4': 27.853,
#   'amplitude': 34.713,
#   'phase_angle': 36.258,
#   'puckering': "C4'-exo",
#   'sugar_class': "~C3'-endo",
#   'bin': '23p',
#   'cluster': '8d',
#   'suiteness': 0.558,
#   'filter_rmsd': 0.069,
#   'frame': {'rmsd': 0.06,
#    'origin': [65.605, 136.367, 46.116],
#    'x_axis': [0.589, 0.212, -0.78],
#    'y_axis': [0.739, 0.248, 0.626],
#    'z_axis': [0.326, -0.945, -0.011],
#    'quaternion': [0.676, 0.581, 0.409, -0.195]}},
#  {'index': 29,
#   'index_chain': 29,
#   'chain_name': ' ',
#   'nt_resnum': 29,
#   'nt_name': 'A',
#   'nt_code': 'A',
#   'nt_id': '1:A29',
#   'linked_nts': ['1:C28', '1:C30'],
#   'nt_type': 'RNA',
#   'dbn': '.',
#   'summary': "anti,~C2'-endo,BI,non-pair-contact,internal-loop,phosphate,splayed-apart",
#   'alpha': 68.973,
#   'beta': 164.025,
#   'gamma': -60.326,
#   'delta': 136.257,
#   'epsilon': -163.781,
#   'zeta': -89.744,
#   'epsilon_zeta': -74.037,
#   'bb_type': 'BI',
#   'chi': -50.432,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-4.664, 6.421, -2.75],
#   'P_xyz': [-5.583, 8.31, -4.251],
#   'form': '.',
#   'ssZp': 1.667,
#   'Dp': 2.564,
#   'splay_angle': 95.433,
#   'splay_distance': 15.311,
#   'splay_ratio': 0.741,
#   'eta': -141.24,
#   'theta': -155.01,
#   'eta_prime': -101.091,
#   'theta_prime': -161.462,
#   'eta_base': -84.806,
#   'theta_base': -155.373,
#   'v0': -40.881,
#   'v1': 48.101,
#   'v2': -35.832,
#   'v3': 15.101,
#   'v4': 14.921,
#   'amplitude': 46.005,
#   'phase_angle': 141.157,
#   'puckering': "C1'-exo",
#   'sugar_class': "~C2'-endo",
#   'bin': '32m',
#   'cluster': '5r',
#   'suiteness': 0.195,
#   'filter_rmsd': 0.05,
#   'frame': {'rmsd': 0.034,
#    'origin': [80.739, 140.847, 53.83],
#    'x_axis': [0.689, -0.144, 0.71],
#    'y_axis': [-0.261, -0.964, 0.058],
#    'z_axis': [0.676, -0.225, -0.702],
#    'quaternion': [0.077, 0.916, -0.111, 0.378]}},
#  {'index': 30,
#   'index_chain': 30,
#   'chain_name': ' ',
#   'nt_resnum': 30,
#   'nt_name': 'C',
#   'nt_code': 'C',
#   'nt_id': '1:C30',
#   'linked_nts': ['1:A29', '1:C31'],
#   'nt_type': 'RNA',
#   'dbn': '.',
#   'summary': "turn,anti,~C2'-endo,non-pair-contact,internal-loop,splayed-apart",
#   'alpha': -74.255,
#   'beta': 164.381,
#   'gamma': -179.117,
#   'delta': 150.186,
#   'epsilon': -156.828,
#   'zeta': 96.597,
#   'epsilon_zeta': 106.575,
#   'bb_type': '--',
#   'chi': -151.5,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-2.351, 8.842, 0.213],
#   'P_xyz': [-1.229, 10.857, -0.974],
#   'form': '.',
#   'ssZp': 1.749,
#   'Dp': 2.535,
#   'splay_angle': 93.905,
#   'splay_distance': 13.231,
#   'splay_ratio': 0.731,
#   'eta': -40.428,
#   'theta': 67.341,
#   'eta_prime': -34.182,
#   'theta_prime': 128.98,
#   'eta_base': -18.434,
#   'theta_base': 175.91,
#   'v0': -34.055,
#   'v1': 47.511,
#   'v2': -42.194,
#   'v3': 25.169,
#   'v4': 6.249,
#   'amplitude': 46.847,
#   'phase_angle': 154.246,
#   'puckering': "C2'-endo",
#   'sugar_class': "~C2'-endo",
#   'bin': '22t',
#   'cluster': '!!',
#   'suiteness': 0.0,
#   'filter_rmsd': 0.06,
#   'frame': {'rmsd': 0.037,
#    'origin': [85.993, 127.777, 47.831],
#    'x_axis': [-0.41, -0.786, -0.464],
#    'y_axis': [-0.9, 0.431, 0.065],
#    'z_axis': [0.149, 0.444, -0.884],
#    'quaternion': [0.186, -0.511, 0.825, 0.154]}},
#  {'index': 31,
#   'index_chain': 31,
#   'chain_name': ' ',
#   'nt_resnum': 31,
#   'nt_name': 'C',
#   'nt_code': 'C',
#   'nt_id': '1:C31',
#   'linked_nts': ['1:C30', '1:U32'],
#   'nt_type': 'RNA',
#   'dbn': '(',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix-end,stem-end,internal-loop,phosphate,splayed-apart",
#   'alpha': 81.106,
#   'beta': 93.051,
#   'gamma': 42.453,
#   'delta': 84.816,
#   'epsilon': -174.735,
#   'zeta': -85.066,
#   'epsilon_zeta': -89.669,
#   'bb_type': 'BI',
#   'chi': -146.811,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-2.425, 9.1, -0.301],
#   'P_xyz': [0.135, 9.242, -0.959],
#   'form': '.',
#   'ssZp': 4.06,
#   'Dp': 4.046,
#   'splay_angle': 23.624,
#   'splay_distance': 3.87,
#   'splay_ratio': 0.205,
#   'eta': -107.499,
#   'theta': -154.803,
#   'eta_prime': -153.411,
#   'theta_prime': -168.053,
#   'eta_base': 179.82,
#   'theta_base': -164.159,
#   'v0': -19.851,
#   'v1': -4.906,
#   'v2': 25.895,
#   'v3': -38.193,
#   'v4': 36.984,
#   'amplitude': 39.09,
#   'phase_angle': 48.513,
#   'puckering': "C4'-exo",
#   'sugar_class': "~C3'-endo",
#   'bin': '23p',
#   'cluster': '!!',
#   'suiteness': 0.0,
#   'filter_rmsd': 0.074,
#   'frame': {'rmsd': 0.037,
#    'origin': [92.026, 139.416, 49.62],
#    'x_axis': [0.137, -0.369, -0.919],
#    'y_axis': [-0.962, -0.271, -0.035],
#    'z_axis': [-0.236, 0.889, -0.393],
#    'quaternion': [-0.344, 0.671, -0.496, -0.43]}},
#  {'index': 32,
#   'index_chain': 32,
#   'chain_name': ' ',
#   'nt_resnum': 32,
#   'nt_name': 'U',
#   'nt_code': 'U',
#   'nt_id': '1:U32',
#   'linked_nts': ['1:C31', '1:G33'],
#   'nt_type': 'RNA',
#   'dbn': '(',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem",
#   'alpha': -101.179,
#   'beta': 172.538,
#   'gamma': 84.523,
#   'delta': 78.349,
#   'epsilon': -149.794,
#   'zeta': -77.867,
#   'epsilon_zeta': -71.927,
#   'bb_type': 'BI',
#   'chi': -153.407,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.597, 8.812, -0.212],
#   'P_xyz': [0.722, 9.482, -1.022],
#   'form': 'A',
#   'ssZp': 3.957,
#   'Dp': 4.701,
#   'splay_angle': 27.061,
#   'splay_distance': 4.22,
#   'splay_ratio': 0.235,
#   'eta': 159.573,
#   'theta': -148.835,
#   'eta_prime': 163.316,
#   'theta_prime': -149.423,
#   'eta_base': -176.992,
#   'theta_base': -121.859,
#   'v0': 2.52,
#   'v1': -32.028,
#   'v2': 45.509,
#   'v3': -45.136,
#   'v4': 26.38,
#   'amplitude': 47.067,
#   'phase_angle': 14.785,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '!!',
#   'suiteness': 0.0,
#   'filter_rmsd': 0.134,
#   'frame': {'rmsd': 0.069,
#    'origin': [92.575, 143.226, 49.223],
#    'x_axis': [-0.138, -0.56, -0.817],
#    'y_axis': [-0.987, 0.014, 0.157],
#    'z_axis': [-0.076, 0.828, -0.555],
#    'quaternion': [0.283, -0.592, 0.653, 0.377]}},
#  {'index': 33,
#   'index_chain': 33,
#   'chain_name': ' ',
#   'nt_resnum': 33,
#   'nt_name': 'G',
#   'nt_code': 'G',
#   'nt_id': '1:G33',
#   'linked_nts': ['1:U32', '1:A34'],
#   'nt_type': 'RNA',
#   'dbn': '(',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem",
#   'alpha': -64.254,
#   'beta': 174.369,
#   'gamma': 52.117,
#   'delta': 82.825,
#   'epsilon': -152.613,
#   'zeta': -66.752,
#   'epsilon_zeta': -85.861,
#   'bb_type': 'BI',
#   'chi': -167.473,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.72, 8.611, 0.974],
#   'P_xyz': [0.907, 9.091, 1.058],
#   'form': 'A',
#   'ssZp': 4.875,
#   'Dp': 4.749,
#   'splay_angle': 20.368,
#   'splay_distance': 3.331,
#   'splay_ratio': 0.183,
#   'eta': 167.85,
#   'theta': -141.282,
#   'eta_prime': 178.557,
#   'theta_prime': -142.345,
#   'eta_base': -140.82,
#   'theta_base': -119.109,
#   'v0': 5.732,
#   'v1': -29.681,
#   'v2': 37.709,
#   'v3': -37.011,
#   'v4': 20.313,
#   'amplitude': 38.375,
#   'phase_angle': 10.692,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.943,
#   'filter_rmsd': 0.079,
#   'frame': {'rmsd': 0.079,
#    'origin': [92.757, 145.273, 45.537],
#    'x_axis': [-0.608, -0.702, -0.371],
#    'y_axis': [-0.721, 0.292, 0.628],
#    'z_axis': [-0.333, 0.649, -0.684],
#    'quaternion': [0.012, -0.443, 0.804, 0.397]}},
#  {'index': 34,
#   'index_chain': 34,
#   'chain_name': ' ',
#   'nt_resnum': 34,
#   'nt_name': 'A',
#   'nt_code': 'A',
#   'nt_id': '1:A34',
#   'linked_nts': ['1:G33', '1:C35'],
#   'nt_type': 'RNA',
#   'dbn': '(',
#   'summary': "anti,~C3'-endo,canonical,non-pair-contact,helix-end,stem-end,hairpin-loop,splayed-apart",
#   'alpha': -79.856,
#   'beta': 170.017,
#   'gamma': 71.735,
#   'delta': 79.411,
#   'epsilon': 148.686,
#   'zeta': 91.4,
#   'epsilon_zeta': 57.286,
#   'bb_type': '--',
#   'chi': -149.595,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.621, 8.676, 0.225],
#   'P_xyz': [0.723, 9.5, -0.532],
#   'form': '.',
#   'ssZp': 4.263,
#   'Dp': 3.963,
#   'splay_angle': 95.511,
#   'splay_distance': 14.5,
#   'splay_ratio': 0.742,
#   'eta': 174.174,
#   'theta': -5.886,
#   'eta_prime': -167.825,
#   'theta_prime': -67.027,
#   'eta_base': -127.769,
#   'theta_base': -117.895,
#   'v0': 2.787,
#   'v1': -24.491,
#   'v2': 33.431,
#   'v3': -32.687,
#   'v4': 20.833,
#   'amplitude': 34.502,
#   'phase_angle': 14.308,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.419,
#   'filter_rmsd': 0.074,
#   'frame': {'rmsd': 0.06,
#    'origin': [92.249, 145.473, 42.25],
#    'x_axis': [-0.902, -0.43, -0.04],
#    'y_axis': [-0.392, 0.775, 0.496],
#    'z_axis': [-0.182, 0.463, -0.868],
#    'quaternion': [-0.038, -0.218, 0.941, 0.254]}},
#  {'index': 35,
#   'index_chain': 35,
#   'chain_name': ' ',
#   'nt_resnum': 35,
#   'nt_name': 'C',
#   'nt_code': 'C',
#   'nt_id': '1:C35',
#   'linked_nts': ['1:A34', '1:C36'],
#   'nt_type': 'RNA',
#   'dbn': '.',
#   'summary': "turn,anti,~C2'-endo,BII,non-stack,non-pair-contact,hairpin-loop,phosphate,splayed-apart",
#   'alpha': 65.351,
#   'beta': 178.766,
#   'gamma': 50.71,
#   'delta': 123.319,
#   'epsilon': -79.893,
#   'zeta': -173.82,
#   'epsilon_zeta': 93.927,
#   'bb_type': 'BII',
#   'chi': -143.627,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-2.325, 9.037, -0.494],
#   'P_xyz': [-0.202, 10.554, -0.2],
#   'form': '.',
#   'ssZp': 1.956,
#   'Dp': 1.524,
#   'splay_angle': 128.538,
#   'splay_distance': 17.937,
#   'splay_ratio': 0.901,
#   'eta': -11.493,
#   'theta': -157.082,
#   'eta_prime': 51.03,
#   'theta_prime': 169.053,
#   'eta_base': 85.736,
#   'theta_base': 135.92,
#   'v0': -29.957,
#   'v1': 29.681,
#   'v2': -20.868,
#   'v3': 3.778,
#   'v4': 16.633,
#   'amplitude': 31.469,
#   'phase_angle': 131.54,
#   'puckering': "C1'-exo",
#   'sugar_class': "~C2'-endo",
#   'bin': 'trig',
#   'cluster': '!!',
#   'suiteness': 0.0,
#   'filter_rmsd': 0.086,
#   'frame': {'rmsd': 0.03,
#    'origin': [87.381, 155.2, 32.661],
#    'x_axis': [0.863, -0.246, -0.442],
#    'y_axis': [0.432, -0.095, 0.897],
#    'z_axis': [-0.263, -0.965, 0.024],
#    'quaternion': [0.669, 0.695, 0.067, -0.253]}},
#  {'index': 36,
#   'index_chain': 36,
#   'chain_name': ' ',
#   'nt_resnum': 36,
#   'nt_name': 'C',
#   'nt_code': 'C',
#   'nt_id': '1:C36',
#   'linked_nts': ['1:C35', '1:C37'],
#   'nt_type': 'RNA',
#   'dbn': '.',
#   'summary': "anti,~C3'-endo,BI,non-pair-contact,hairpin-loop,splayed-apart",
#   'alpha': 63.06,
#   'beta': 173.715,
#   'gamma': 73.293,
#   'delta': 95.379,
#   'epsilon': -158.081,
#   'zeta': -54.54,
#   'epsilon_zeta': -103.541,
#   'bb_type': 'BI',
#   'chi': -159.56,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-2.106, 8.826, 0.225],
#   'P_xyz': [0.243, 9.59, 0.175],
#   'form': '.',
#   'ssZp': 3.88,
#   'Dp': 4.249,
#   'splay_angle': 31.108,
#   'splay_distance': 5.042,
#   'splay_ratio': 0.27,
#   'eta': -16.915,
#   'theta': -119.141,
#   'eta_prime': 13.474,
#   'theta_prime': -123.889,
#   'eta_base': 40.362,
#   'theta_base': -68.2,
#   'v0': -4.306,
#   'v1': -18.758,
#   'v2': 33.064,
#   'v3': -34.906,
#   'v4': 25.006,
#   'amplitude': 36.213,
#   'phase_angle': 24.072,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '23p',
#   'cluster': '!!',
#   'suiteness': 0.0,
#   'filter_rmsd': 0.077,
#   'frame': {'rmsd': 0.039,
#    'origin': [78.897, 158.045, 48.207],
#    'x_axis': [0.692, 0.652, 0.312],
#    'y_axis': [0.687, -0.459, -0.564],
#    'z_axis': [-0.224, 0.604, -0.765],
#    'quaternion': [-0.342, 0.854, 0.392, 0.026]}},
#  {'index': 37,
#   'index_chain': 37,
#   'chain_name': ' ',
#   'nt_resnum': 37,
#   'nt_name': 'C',
#   'nt_code': 'C',
#   'nt_id': '1:C37',
#   'linked_nts': ['1:C36', '1:C38'],
#   'nt_type': 'RNA',
#   'dbn': '.',
# ...
#    'x_axis': [0.99, 0.114, -0.083],
#    'y_axis': [0.009, -0.639, -0.769],
#    'z_axis': [-0.141, 0.761, -0.633],
#    'quaternion': [-0.424, 0.903, 0.034, -0.062]}},
#  {'index': 109,
#   'index_chain': 109,
#   'chain_name': ' ',
#   'nt_resnum': 109,
#   'nt_name': 'A',
#   'nt_code': 'A',
#   'nt_id': '1:A109',
#   'linked_nts': ['1:A108', '1:C110'],
#   'nt_type': 'RNA',
#   'dbn': '.',
#   'summary': "anti,~C3'-endo,non-canonical,non-pair-contact,helix-end,junction-loop,splayed-apart",
#   'alpha': 48.052,
#   'beta': 69.568,
#   'gamma': -179.273,
#   'delta': 101.805,
#   'epsilon': -112.616,
#   'zeta': -71.26,
#   'epsilon_zeta': -41.356,
#   'bb_type': '--',
#   'chi': -175.893,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.505, 8.196, 1.542],
#   'P_xyz': [-2.162, 10.515, 0.623],
#   'form': '.',
#   'ssZp': 4.413,
#   'Dp': 4.809,
#   'splay_angle': 29.066,
#   'splay_distance': 4.618,
#   'splay_ratio': 0.252,
#   'eta': -31.152,
#   'theta': -174.886,
#   'eta_prime': -3.829,
#   'theta_prime': -156.099,
#   'eta_base': 22.848,
#   'theta_base': -89.384,
#   'v0': 9.978,
#   'v1': -30.281,
#   'v2': 38.095,
#   'v3': -30.779,
#   'v4': 14.061,
#   'amplitude': 38.124,
#   'phase_angle': 2.238,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '23t',
#   'cluster': '!!',
#   'suiteness': 0.0,
#   'filter_rmsd': 0.074,
#   'frame': {'rmsd': 0.058,
#    'origin': [105.982, 116.56, 58.934],
#    'x_axis': [-0.198, 0.658, -0.726],
#    'y_axis': [-0.4, 0.622, 0.673],
#    'z_axis': [0.895, 0.424, 0.14],
#    'quaternion': [0.625, 0.1, 0.648, 0.423]}},
#  {'index': 110,
#   'index_chain': 110,
#   'chain_name': ' ',
#   'nt_resnum': 110,
#   'nt_name': 'C',
#   'nt_code': 'C',
#   'nt_id': '1:C110',
#   'linked_nts': ['1:A109', '1:U111'],
#   'nt_type': 'RNA',
#   'dbn': ')',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem-end,junction-loop,phosphate",
#   'alpha': -72.39,
#   'beta': 155.954,
#   'gamma': 61.62,
#   'delta': 80.182,
#   'epsilon': -146.979,
#   'zeta': -50.387,
#   'epsilon_zeta': -96.592,
#   'bb_type': 'BI',
#   'chi': -155.964,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.359, 8.839, 0.253],
#   'P_xyz': [1.174, 9.275, 0.077],
#   'form': '.',
#   'ssZp': 4.003,
#   'Dp': 4.635,
#   'splay_angle': 29.825,
#   'splay_distance': 4.93,
#   'splay_ratio': 0.261,
#   'eta': 148.237,
#   'theta': -122.32,
#   'eta_prime': 179.612,
#   'theta_prime': -122.328,
#   'eta_base': -98.146,
#   'theta_base': -80.627,
#   'v0': 2.767,
#   'v1': -24.533,
#   'v2': 34.562,
#   'v3': -35.041,
#   'v4': 20.775,
#   'amplitude': 35.782,
#   'phase_angle': 15.007,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.054,
#   'filter_rmsd': 0.061,
#   'frame': {'rmsd': 0.045,
#    'origin': [107.487, 120.775, 57.793],
#    'x_axis': [-0.516, 0.82, 0.248],
#    'y_axis': [0.125, -0.214, 0.969],
#    'z_axis': [0.848, 0.531, 0.008],
#    'quaternion': [0.263, 0.416, 0.569, 0.659]}},
#  {'index': 111,
#   'index_chain': 111,
#   'chain_name': ' ',
#   'nt_resnum': 111,
#   'nt_name': 'U',
#   'nt_code': 'U',
#   'nt_id': '1:U111',
#   'linked_nts': ['1:C110', '1:G112'],
#   'nt_type': 'RNA',
#   'dbn': ')',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem",
#   'alpha': -70.854,
#   'beta': 173.627,
#   'gamma': 54.651,
#   'delta': 77.457,
#   'epsilon': -174.699,
#   'zeta': -82.157,
#   'epsilon_zeta': -92.542,
#   'bb_type': 'BI',
#   'chi': -156.526,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.409, 8.882, 0.708],
#   'P_xyz': [1.005, 9.812, 0.487],
#   'form': '.',
#   'ssZp': 4.844,
#   'Dp': 4.266,
#   'splay_angle': 30.573,
#   'splay_distance': 5.017,
#   'splay_ratio': 0.268,
#   'eta': 159.8,
#   'theta': 179.369,
#   'eta_prime': -171.895,
#   'theta_prime': 176.371,
#   'eta_base': -104.184,
#   'theta_base': 160.455,
#   'v0': -9.023,
#   'v1': -15.155,
#   'v2': 30.254,
#   'v3': -38.116,
#   'v4': 28.415,
#   'amplitude': 36.061,
#   'phase_angle': 32.97,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.674,
#   'filter_rmsd': 0.107,
#   'frame': {'rmsd': 0.037,
#    'origin': [108.314, 125.463, 59.074],
#    'x_axis': [-0.233, 0.371, 0.899],
#    'y_axis': [0.501, -0.747, 0.438],
#    'z_axis': [0.834, 0.552, -0.012],
#    'quaternion': [-0.046, 0.618, 0.353, 0.701]}},
#  {'index': 112,
#   'index_chain': 112,
#   'chain_name': ' ',
#   'nt_resnum': 112,
#   'nt_name': 'G',
#   'nt_code': 'G',
#   'nt_id': '1:G112',
#   'linked_nts': ['1:U111', '1:C113'],
#   'nt_type': 'RNA',
#   'dbn': ')',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem",
#   'alpha': -87.85,
#   'beta': 178.397,
#   'gamma': 62.936,
#   'delta': 79.317,
#   'epsilon': -167.055,
#   'zeta': -69.123,
#   'epsilon_zeta': -97.932,
#   'bb_type': 'BI',
#   'chi': -159.779,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.659, 8.998, 0.378],
#   'P_xyz': [0.849, 9.789, 0.338],
#   'form': 'A',
#   'ssZp': 4.367,
#   'Dp': 4.481,
#   'splay_angle': 22.996,
#   'splay_distance': 3.779,
#   'splay_ratio': 0.205,
#   'eta': 158.447,
#   'theta': -149.973,
#   'eta_prime': 159.463,
#   'theta_prime': -152.142,
#   'eta_base': 150.553,
#   'theta_base': -130.794,
#   'v0': -4.041,
#   'v1': -24.514,
#   'v2': 38.763,
#   'v3': -43.042,
#   'v4': 30.305,
#   'amplitude': 42.4,
#   'phase_angle': 23.903,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.345,
#   'filter_rmsd': 0.076,
#   'frame': {'rmsd': 0.076,
#    'origin': [109.859, 126.954, 54.54],
#    'x_axis': [-0.465, 0.158, 0.871],
#    'y_axis': [0.692, -0.548, 0.469],
#    'z_axis': [0.552, 0.821, 0.145],
#    'quaternion': [-0.182, 0.484, 0.439, 0.735]}},
#  {'index': 113,
#   'index_chain': 113,
#   'chain_name': ' ',
#   'nt_resnum': 113,
#   'nt_name': 'C',
#   'nt_code': 'C',
#   'nt_id': '1:C113',
#   'linked_nts': ['1:G112', '1:C114'],
#   'nt_type': 'RNA',
#   'dbn': ')',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem",
#   'alpha': -77.592,
#   'beta': 171.479,
#   'gamma': 69.596,
#   'delta': 75.601,
#   'epsilon': -172.589,
#   'zeta': -62.915,
#   'epsilon_zeta': -109.674,
#   'bb_type': 'BI',
#   'chi': -160.041,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.852, 8.83, 0.641],
#   'P_xyz': [0.732, 9.628, 0.543],
#   'form': 'A',
#   'ssZp': 4.387,
#   'Dp': 4.738,
#   'splay_angle': 26.444,
#   'splay_distance': 4.287,
#   'splay_ratio': 0.235,
#   'eta': 165.782,
#   'theta': -150.847,
#   'eta_prime': 178.9,
#   'theta_prime': -150.785,
#   'eta_base': -143.609,
#   'theta_base': -127.772,
#   'v0': -0.303,
#   'v1': -29.428,
#   'v2': 42.539,
#   'v3': -45.02,
#   'v4': 30.531,
#   'amplitude': 45.134,
#   'phase_angle': 19.525,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.445,
#   'filter_rmsd': 0.07,
#   'frame': {'rmsd': 0.054,
#    'origin': [110.043, 130.718, 54.836],
#    'x_axis': [-0.145, -0.221, 0.965],
#    'y_axis': [0.867, -0.499, 0.016],
#    'z_axis': [0.477, 0.838, 0.264],
#    'quaternion': [-0.394, 0.522, 0.309, 0.69]}},
#  {'index': 114,
#   'index_chain': 114,
#   'chain_name': ' ',
#   'nt_resnum': 114,
#   'nt_name': 'C',
#   'nt_code': 'C',
#   'nt_id': '1:C114',
#   'linked_nts': ['1:C113', '1:A115'],
#   'nt_type': 'RNA',
#   'dbn': ')',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem",
#   'alpha': -71.987,
#   'beta': 178.47,
#   'gamma': 63.372,
#   'delta': 73.76,
#   'epsilon': -158.837,
#   'zeta': -62.711,
#   'epsilon_zeta': -96.126,
#   'bb_type': 'BI',
#   'chi': -160.459,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.636, 8.991, 0.786],
#   'P_xyz': [0.874, 9.476, 1.451],
#   'form': 'A',
#   'ssZp': 4.235,
#   'Dp': 4.592,
#   'splay_angle': 19.74,
#   'splay_distance': 3.159,
#   'splay_ratio': 0.172,
#   'eta': 175.868,
#   'theta': -144.659,
#   'eta_prime': -172.5,
#   'theta_prime': -142.359,
#   'eta_base': -137.172,
#   'theta_base': -112.615,
#   'v0': 9.41,
#   'v1': -33.105,
#   'v2': 43.321,
#   'v3': -37.628,
#   'v4': 17.913,
#   'amplitude': 43.527,
#   'phase_angle': 5.58,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.497,
#   'filter_rmsd': 0.07,
#   'frame': {'rmsd': 0.057,
#    'origin': [109.968, 134.598, 56.655],
#    'x_axis': [0.255, -0.591, 0.765],
#    'y_axis': [0.774, -0.349, -0.528],
#    'z_axis': [0.579, 0.727, 0.369],
#    'quaternion': [0.565, -0.556, -0.082, -0.605]}},
#  {'index': 115,
#   'index_chain': 115,
#   'chain_name': ' ',
#   'nt_resnum': 115,
#   'nt_name': 'A',
#   'nt_code': 'A',
#   'nt_id': '1:A115',
#   'linked_nts': ['1:C114', '1:G116'],
#   'nt_type': 'RNA',
#   'dbn': ')',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem,A-minor",
#   'alpha': -82.754,
#   'beta': 173.296,
#   'gamma': 59.395,
#   'delta': 79.416,
#   'epsilon': -148.084,
#   'zeta': -79.966,
#   'epsilon_zeta': -68.118,
#   'bb_type': 'BI',
#   'chi': -152.521,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.857, 8.688, 0.199],
#   'P_xyz': [0.623, 9.301, 0.083],
#   'form': 'A',
#   'ssZp': 4.235,
#   'Dp': 4.612,
#   'splay_angle': 26.236,
#   'splay_distance': 4.177,
#   'splay_ratio': 0.23,
#   'eta': 156.748,
#   'theta': -151.017,
#   'eta_prime': 173.053,
#   'theta_prime': -154.189,
#   'eta_base': -142.259,
#   'theta_base': -130.322,
#   'v0': 12.093,
#   'v1': -34.945,
#   'v2': 42.523,
#   'v3': -38.607,
#   'v4': 17.711,
#   'amplitude': 42.629,
#   'phase_angle': 4.056,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.607,
#   'filter_rmsd': 0.071,
#   'frame': {'rmsd': 0.054,
#    'origin': [111.038, 136.623, 58.831],
#    'x_axis': [0.603, -0.719, 0.345],
#    'y_axis': [0.596, 0.119, -0.794],
#    'z_axis': [0.53, 0.685, 0.5],
#    'quaternion': [0.745, -0.496, 0.062, -0.441]}},
#  {'index': 116,
#   'index_chain': 116,
#   'chain_name': ' ',
#   'nt_resnum': 116,
#   'nt_name': 'G',
#   'nt_code': 'G',
#   'nt_id': '1:G116',
#   'linked_nts': ['1:A115', '1:G117'],
#   'nt_type': 'RNA',
#   'dbn': ')',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem",
#   'alpha': -58.249,
#   'beta': 167.445,
#   'gamma': 59.725,
#   'delta': 80.818,
#   'epsilon': -148.435,
#   'zeta': -71.487,
#   'epsilon_zeta': -76.948,
#   'bb_type': 'BI',
#   'chi': -166.861,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.155, 8.738, 1.226],
#   'P_xyz': [1.352, 9.245, 1.303],
#   'form': 'A',
#   'ssZp': 4.837,
#   'Dp': 4.817,
#   'splay_angle': 21.745,
#   'splay_distance': 3.591,
#   'splay_ratio': 0.195,
#   'eta': 173.224,
#   'theta': -145.84,
#   'eta_prime': -179.487,
#   'theta_prime': -144.694,
#   'eta_base': -141.641,
#   'theta_base': -122.026,
#   'v0': 3.923,
#   'v1': -25.994,
#   'v2': 35.898,
#   'v3': -34.292,
#   'v4': 20.885,
#   'amplitude': 36.824,
#   'phase_angle': 12.879,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.868,
#   'filter_rmsd': 0.085,
#   'frame': {'rmsd': 0.085,
#    'origin': [112.708, 138.281, 62.282],
#    'x_axis': [0.73, -0.648, -0.217],
#    'y_axis': [0.137, 0.449, -0.883],
#    'z_axis': [0.67, 0.614, 0.416],
#    'quaternion': [0.806, -0.465, 0.275, -0.244]}},
#  {'index': 117,
#   'index_chain': 117,
#   'chain_name': ' ',
#   'nt_resnum': 117,
#   'nt_name': 'G',
#   'nt_code': 'G',
#   'nt_id': '1:G117',
#   'linked_nts': ['1:G116', '1:C118'],
#   'nt_type': 'RNA',
#   'dbn': ')',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem",
#   'alpha': -71.279,
#   'beta': 172.405,
#   'gamma': 60.767,
#   'delta': 73.157,
#   'epsilon': -161.242,
#   'zeta': -63.358,
#   'epsilon_zeta': -97.884,
#   'bb_type': 'BI',
#   'chi': -158.206,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.615, 8.864, 0.554],
#   'P_xyz': [0.943, 9.596, 0.664],
#   'form': 'A',
#   'ssZp': 4.198,
#   'Dp': 4.636,
#   'splay_angle': 21.687,
#   'splay_distance': 3.522,
#   'splay_ratio': 0.193,
#   'eta': 162.995,
#   'theta': -152.887,
#   'eta_prime': -179.94,
#   'theta_prime': -151.017,
#   'eta_base': -140.023,
#   'theta_base': -128.106,
#   'v0': 11.28,
#   'v1': -31.818,
#   'v2': 40.056,
#   'v3': -35.308,
#   'v4': 15.309,
#   'amplitude': 40.13,
#   'phase_angle': 3.49,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.767,
#   'filter_rmsd': 0.079,
#   'frame': {'rmsd': 0.079,
#    'origin': [115.095, 138.453, 64.96],
#    'x_axis': [0.59, -0.412, -0.694],
#    'y_axis': [-0.133, 0.799, -0.587],
#    'z_axis': [0.796, 0.439, 0.416],
#    'quaternion': [0.837, -0.306, 0.445, -0.083]}},
#  {'index': 118,
#   'index_chain': 118,
#   'chain_name': ' ',
#   'nt_resnum': 118,
#   'nt_name': 'C',
#   'nt_code': 'C',
#   'nt_id': '1:C118',
#   'linked_nts': ['1:G117', '1:A119'],
#   'nt_type': 'RNA',
#   'dbn': ')',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix,stem",
#   'alpha': -82.38,
#   'beta': -175.388,
#   'gamma': 64.616,
#   'delta': 88.448,
#   'epsilon': -144.364,
#   'zeta': -79.002,
#   'epsilon_zeta': -65.362,
#   'bb_type': 'BI',
#   'chi': -157.965,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.531, 9.025, 0.382],
#   'P_xyz': [1.005, 9.466, 0.067],
#   'form': 'A',
#   'ssZp': 4.523,
#   'Dp': 4.568,
#   'splay_angle': 22.795,
#   'splay_distance': 3.76,
#   'splay_ratio': 0.202,
#   'eta': 168.449,
#   'theta': -138.271,
#   'eta_prime': -178.994,
#   'theta_prime': -141.331,
#   'eta_base': -142.966,
#   'theta_base': -117.506,
#   'v0': 8.043,
#   'v1': -27.557,
#   'v2': 36.605,
#   'v3': -31.875,
#   'v4': 15.167,
#   'amplitude': 36.793,
#   'phase_angle': 5.799,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.477,
#   'filter_rmsd': 0.083,
#   'frame': {'rmsd': 0.041,
#    'origin': [118.065, 138.121, 66.822],
#    'x_axis': [0.543, 0.083, -0.836],
#    'y_axis': [-0.322, 0.939, -0.116],
#    'z_axis': [0.776, 0.332, 0.536],
#    'quaternion': [0.869, -0.129, 0.464, 0.117]}},
#  {'index': 119,
#   'index_chain': 119,
#   'chain_name': ' ',
#   'nt_resnum': 119,
#   'nt_name': 'A',
#   'nt_code': 'A',
#   'nt_id': '1:A119',
#   'linked_nts': ['1:C118', '1:U120'],
#   'nt_type': 'RNA',
#   'dbn': ')',
#   'summary': "anti,~C3'-endo,BI,canonical,non-pair-contact,helix-end,stem-end",
#   'alpha': -77.297,
#   'beta': 172.573,
#   'gamma': 58.793,
#   'delta': 74.588,
#   'epsilon': -167.113,
#   'zeta': -76.738,
#   'epsilon_zeta': -90.375,
#   'bb_type': 'BI',
#   'chi': -163.182,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.79, 8.716, 0.495],
#   'P_xyz': [0.602, 9.684, 0.16],
#   'form': '.',
#   'ssZp': 4.441,
#   'Dp': 4.625,
#   'splay_angle': 26.26,
#   'splay_distance': 4.482,
#   'splay_ratio': 0.245,
#   'eta': 157.126,
#   'theta': -168.874,
#   'eta_prime': 172.501,
#   'theta_prime': -170.026,
#   'eta_base': -143.756,
#   'theta_base': -175.68,
#   'v0': 5.426,
#   'v1': -29.487,
#   'v2': 40.184,
#   'v3': -39.515,
#   'v4': 20.945,
#   'amplitude': 41.032,
#   'phase_angle': 11.671,
#   'puckering': "C3'-endo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.705,
#   'filter_rmsd': 0.071,
#   'frame': {'rmsd': 0.062,
#    'origin': [121.82, 138.031, 66.988],
#    'x_axis': [0.069, 0.454, -0.888],
#    'y_axis': [-0.414, 0.823, 0.389],
#    'z_axis': [0.908, 0.341, 0.245],
#    'quaternion': [0.731, 0.017, 0.614, 0.297]}},
#  {'index': 120,
#   'index_chain': 120,
#   'chain_name': ' ',
#   'nt_resnum': 120,
#   'nt_name': 'U',
#   'nt_code': 'U',
#   'nt_id': '1:U120',
#   'linked_nts': ['1:A119', None],
#   'nt_type': 'RNA',
#   'dbn': '.',
#   'summary': "anti,~C3'-endo,non-pair-contact,ss-non-loop",
#   'alpha': -62.335,
#   'beta': 173.671,
#   'gamma': 61.688,
#   'delta': 84.531,
#   'epsilon': None,
#   'zeta': None,
#   'epsilon_zeta': None,
#   'bb_type': '--',
#   'chi': -160.681,
#   'glyco_bond': 'anti',
#   'C5prime_xyz': [-1.892, 9.106, 0.349],
#   'P_xyz': [0.597, 9.996, 0.188],
#   'form': '-',
#   'ssZp': None,
#   'Dp': None,
#   'splay_angle': None,
#   'splay_distance': None,
#   'splay_ratio': None,
#   'eta': None,
#   'theta': None,
#   'eta_prime': None,
#   'theta_prime': None,
#   'eta_base': None,
#   'theta_base': None,
#   'v0': -17.942,
#   'v1': -9.0,
#   'v2': 29.964,
#   'v3': -40.876,
#   'v4': 39.003,
#   'amplitude': 41.602,
#   'phase_angle': 43.924,
#   'puckering': "C4'-exo",
#   'sugar_class': "~C3'-endo",
#   'bin': '33p',
#   'cluster': '1a',
#   'suiteness': 0.653,
#   'filter_rmsd': 0.091,
#   'frame': {'rmsd': 0.034,
#    'origin': [125.462, 135.545, 67.795],
#    'x_axis': [-0.072, 0.553, -0.83],
#    'y_axis': [-0.264, 0.792, 0.551],
#    'z_axis': [0.962, 0.259, 0.089],
#    'quaternion': [0.672, 0.108, 0.666, 0.304]}}]

# %%
for field, categories in MINIMAL_CATEGORIES.items():
    print(field)
# Out:
# puckering
# sugar_class
# form
# glyco_bond
# bb_type

# %%
# MINIMAL fixed categories
MINIMAL_CATEGORIES = {
    'puckering': ["C3'-endo", "C2'-endo", "other"],
    'sugar_class': ["~C3'-endo", "~C2'-endo", "other"],
    'form': ['A', 'B', 'other'],
    'glyco_bond': ['anti', 'syn', 'other'],
    'bb_type': ['BI', 'BII', 'other']
}

# Initialize matrices
conformational_features = {}
for field, categories in MINIMAL_CATEGORIES.items():
    conformational_features[field] = {cat: np.zeros((n_nt, n_frames), dtype=np.uint8) for cat in categories}

# Extract conformational states
for f, m in enumerate(models):
    for nt in m['parameters'].get('nts', []):
        nt_name = nt['nt_id'].split(':')[1]
        if nt_name not in nt_index:
            continue
        
        i = nt_index[nt_name]
        
        for field, categories in MINIMAL_CATEGORIES.items():
            value = nt.get(field, '')
            category = value if value in categories else 'other'
            conformational_features[field][category][i, f] = 1

# Calculate fractions and build DataFrame
conformational_probs = {}
for field, matrices in conformational_features.items():
    for category, matrix in matrices.items():
        col_name = f"{field}_{category}".replace("'", "").replace("-", "_").replace("~", "")
        conformational_probs[col_name] = matrix.mean(axis=1)

conformational_df = pd.DataFrame(conformational_probs, index=nt_ids)
conformational_df.insert(0, 'nucleotide', nt_ids)

# Combine with structural features
ml_features_df = features_df.merge(conformational_df, on='nucleotide')
ml_features_df.to_csv('dssr_ml_features.csv', index=False)

print(f"ML features saved: {ml_features_df.shape[0]} nucleotides × {ml_features_df.shape[1]-1} features")
# Out:
# ML features saved: 120 nucleotides × 24 features

# %%
ml_features_df
# Out:
#     nucleotide  fraction_paired  fraction_wc_paired  fraction_non_wc_paired  \
# 0           U1         0.804797            0.734177                0.123251
# 1           G2         0.999334            0.997335                0.003331
# 2           C3         1.000000            1.000000                0.003331
# 3           C4         1.000000            1.000000                0.007328
# 4           U5         0.999334            0.996669                0.012658
# 5           G6         1.000000            1.000000                0.007328
# 6           G7         1.000000            1.000000                0.000000
# 7           C8         1.000000            1.000000                0.000000
# 8           G9         0.758827            0.757495                0.001332
# 9          G10         0.658228            0.656895                0.019320
# 10         C11         0.014657            0.000000                0.014657
# 11         C12         0.392405            0.329780                0.177215
# 12         G13         0.411059            0.084610                0.377082
# 13         U14         0.017322            0.000000                0.017322
